# %%
import os
import random
import csv
from pathlib import Path
import random
import re
import pandas as pd
import numpy as np
from unidecode import unidecode
from nltk.corpus import stopwords
import spacy
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# ----------------------------------------
# 1. Parameters, paths and models
# ----------------------------------------

# Path & Parameters 
project_root = Path().resolve().parent
attribute_file = project_root / "data" / "attribute_base_processedV2.xlsx"
jocas_dir = "/Users/alfonso/Desktop/JOCAS"  # adjust if needed
output_file = Path(project_root) / "data" / "attribute_base_processedV3.xlsx"

# Parameters
SAMPLE_SIZE = 100000
RANDOM_SEED = 42

# Minimal cleaning + unaccenting
def clean_text(text: str) -> str:
    s = re.sub(r"http\S+|www\.\S+", " ", text)
    return re.sub(r"\s+", " ", s).strip()

# Load SpaCy with parser 
nlp = spacy.load("fr_core_news_sm", disable=["ner"])

# Load SBERT 
sbert = SentenceTransformer("distiluse-base-multilingual-cased-v2")

# Stop-words 
french_stopwords = set(stopwords.words("french"))


# ----------------------------------------
# 2. Build seed-token sets per category
# ----------------------------------------
attribute_df = (
    pd.read_excel(attribute_file)
      .loc[:, ["attribute_category_fr", "expression"]]
      .dropna()
)

cat_to_seeds = {}
for cat, grp in attribute_df.groupby("attribute_category_fr"):
    seeds = set()
    for expr in grp["expression"].astype(str):
        toks = clean_text(expr).split()
        seeds.update([tok for tok in toks if tok not in french_stopwords])
    cat_to_seeds[cat] = seeds

# %%
# ----------------------------------------
# 3. Ingest & Aggregate JOCAS Job Ads
# ----------------------------------------

# Initialize container
jocas_list = []


# Walk though source folders
for source_folder in os.listdir(jocas_dir):
    source_path = os.path.join(jocas_dir, source_folder)
    
    if os.path.isdir(source_path):
        # Collect all csv files under this source
        csv_files = []
        for root, dirs, files in os.walk(source_path):
            for file in files:
                
                # Case-insensitive check for .csv files
                if file.lower().endswith('.csv'):
                    csv_files.append(os.path.join(root, file))
        
        print(f"Found {len(csv_files)} CSV files in source folder: {source_folder}")
        
        if not csv_files:
            continue
        
        # Select up to 50 csv files from this source
        if len(csv_files) > 50:
            selected_files = random.sample(csv_files, 50)
        else:
            selected_files = csv_files
        
        print(f"Processing {len(selected_files)} files from source folder: {source_folder}")
        
        # Process each selected CSV file
        for file_path in selected_files:
            try:
                df = pd.read_csv(
                    file_path,
                    header=0,
                    sep=';',
                    on_bad_lines='skip',
                    low_memory=False,
                    quoting=csv.QUOTE_MINIMAL,
                    escapechar='\\'
                )
                jocas_list.append(df)
            except Exception as e:
                print(f"Failed to read {file_path}: {e}")

        print(f"Finished processing source folder: {source_folder}")

# Aggregate all dataframes into one
df_job = pd.concat(jocas_list, ignore_index=True)
print(f"Total job ads: {len(df_job)}")
# Out:
# Found 361 CSV files in source folder: regionsjob_nord
# Processing 50 files from source folder: regionsjob_nord
# Finished processing source folder: regionsjob_nord
# Found 357 CSV files in source folder: regionsjob_paris
# Processing 50 files from source folder: regionsjob_paris
# Finished processing source folder: regionsjob_paris
# Found 359 CSV files in source folder: regionsjob_rhonealpes
# Processing 50 files from source folder: regionsjob_rhonealpes
# Finished processing source folder: regionsjob_rhonealpes
# Found 362 CSV files in source folder: apec
# Processing 50 files from source folder: apec
# Finished processing source folder: apec
# Found 169 CSV files in source folder: keljob
# Processing 50 files from source folder: keljob
# Finished processing source folder: keljob
# Found 360 CSV files in source folder: regionsjob_sudouest
# Processing 50 files from source folder: regionsjob_sudouest
# Finished processing source folder: regionsjob_sudouest
# Found 361 CSV files in source folder: regionsjob_paca
# Processing 50 files from source folder: regionsjob_paca
# Finished processing source folder: regionsjob_paca
# Found 152 CSV files in source folder: viadeo
# Processing 50 files from source folder: viadeo
# Finished processing source folder: viadeo
# Found 358 CSV files in source folder: regionsjob_ouest
# Processing 50 files from source folder: regionsjob_ouest
# Finished processing source folder: regionsjob_ouest
# Found 319 CSV files in source folder: jobintree
# Processing 50 files from source folder: jobintree
# Finished processing source folder: jobintree
# Found 356 CSV files in source folder: regionsjob_centre
# Processing 50 files from source folder: regionsjob_centre
# Finished processing source folder: regionsjob_centre
# Found 362 CSV files in source folder: cadreo
# Processing 50 files from source folder: cadreo
# Finished processing source folder: cadreo
# Found 354 CSV files in source folder: leboncoin
# Processing 50 files from source folder: leboncoin
# Finished processing source folder: leboncoin
# Found 170 CSV files in source folder: cadremploi
# Processing 50 files from source folder: cadremploi
# Finished processing source folder: cadremploi
# Found 361 CSV files in source folder: regionsjob_est
# Processing 50 files from source folder: regionsjob_est
# Finished processing source folder: regionsjob_est
# Found 14 CSV files in source folder: meteojob
# Processing 14 files from source folder: meteojob
# Finished processing source folder: meteojob
# Found 348 CSV files in source folder: bdm
# Processing 50 files from source folder: bdm
# Finished processing source folder: bdm
# Found 363 CSV files in source folder: api_poleemploi
# Processing 50 files from source folder: api_poleemploi
# Finished processing source folder: api_poleemploi
# /var/folders/5z/n4wfh12s55d5j381j6gl47c40000gn/T/ipykernel_7007/3032757085.py:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_job = pd.concat(jocas_list, ignore_index=True)
# Total job ads: 2017548

# %%
# ----------------------------------------
# 4. Sample & clean job descriptions
# ----------------------------------------
raw = (
    df_job["description_full"]
      .dropna()
      .astype(str)
      .sample(n=SAMPLE_SIZE, random_state=RANDOM_SEED)
      .tolist()
)
cleaned_texts = [clean_text(t) for t in raw]

# ----------------------------------------
# 5. Extract noun-chunks as candidates
# ----------------------------------------
candidate_phrases = {cat: set() for cat in cat_to_seeds}
for sent in cleaned_texts:
    doc = nlp(sent)
    for chunk in doc.noun_chunks:
        phrase = clean_text(chunk.text)
        toks = phrase.split()
        # keep only chunks of length 3–7
        if 3 <= len(toks) <= 7:
            for cat, seeds in cat_to_seeds.items():
                if any(tok in seeds for tok in toks):
                    candidate_phrases[cat].add(phrase)

# debug
for cat, phs in candidate_phrases.items():
    print(f"{cat}: {len(phs)} candidates")

# ----------------------------------------
# 6. Compute category centroids
# ----------------------------------------
cat_centroids = {}
for cat, grp in attribute_df.groupby("attribute_category_fr"):
    exprs = grp["expression"].astype(str).tolist()
    exprs_clean = [clean_text(e) for e in exprs]
    emb = sbert.encode(exprs_clean, convert_to_numpy=True)
    cat_centroids[cat] = emb.mean(axis=0, keepdims=True)

# ----------------------------------------
# 7. Score & select top-30 per category
# ----------------------------------------
results = []
for cat, centroid in cat_centroids.items():
    cands = list(candidate_phrases[cat])
    if not cands:
        continue
    cand_embs = sbert.encode(cands, convert_to_numpy=True)
    sims = cosine_similarity(centroid, cand_embs)[0]
    top_idx = np.argsort(sims)[::-1][:30]
    for idx in top_idx:
        results.append({
            "attribute_category_fr": cat,
            "suggested_expression": cands[idx],
            "similarity": float(sims[idx])
        })

# ----------------------------------------
# 8. Preview top-5 per category
# ----------------------------------------
results_df = pd.DataFrame(results)
preview = (
    results_df
      .sort_values(["attribute_category_fr", "similarity"], ascending=[True, False])
      .groupby("attribute_category_fr")
      .head(5)
      .reset_index(drop=True)
)
print(preview.to_string(index=False))
# Out:
# Autonomie dans l’exécution des tâches: 8265 candidates
# Bel emplacement: 5389 candidates
# Bonne rémunération des heures supplémentaires: 6179 candidates
# Bonnes perspectives de carrière: 11091 candidates
# Bons collègues: 8582 candidates
# Chalet d’entreprise: 1388 candidates
# Choix entre temps plein et temps partiel: 3777 candidates
# Chèques vacance: 8 candidates
# Congés flexibles/étendus: 3885 candidates
# Contrat à durée déterminée: 4382 candidates
# Contrat à temps partiel: 708 candidates
# Contrat à temps plein: 875 candidates
# Emplacement central: 1715 candidates
# Emploi permanent: 4227 candidates
# Emploi sur appel: 4780 candidates
# Emploi temporaire: 3971 candidates
# Environnement social: 12390 candidates
# Espace de bureau partagé: 3960 candidates
# Exemption des réglementations sur le temps de travail: 9922 candidates
# Formation en cours d’emploi: 12260 candidates
# Heures supplémentaires requises: 9429 candidates
# Horaire de travail de jour régulier: 3609 candidates
# Niveau de rémunération: 6287 candidates
# Place de parking sur site: 1303 candidates
# Possibilité de télétravail: 8189 candidates
# Possibilité d’emprunt immobilier: 1333 candidates
# Possibilité d’horaires flexibles: 3744 candidates
# Prime à l’embauche: 545 candidates
# Programme d’inclusion travail-vie personnelle: 10334 candidates
# Responsabilité de leadership incluse: 8993 candidates
# Responsabilités dans le poste: 7965 candidates
# Régime de retraite: 2858 candidates
# Régime d’assurance: 2688 candidates
# Salaire compétitif: 1839 candidates
# Salaire selon convention collective: 1222 candidates
# Salle de sport ou équipe sportive de l’entreprise: 3741 candidates
# Service de santé au travail: 6264 candidates
# Système de rémunération incitative: 2714 candidates
# Tickets restaurants: 11 candidates
# Tout programme de bien-être: 5515 candidates
# Toute autre mention de salaire: 8226 candidates
# Travail impliquant des déplacements: 2444 candidates
# Travail le week-end/soir/nuit: 4472 candidates
# Travail par postes: 6401 candidates
# Tâches intéressantes: 6308 candidates
# Tâches stimulantes: 4343 candidates
# Variété des tâches: 7587 candidates
# Véhicule de fonction: 3665 candidates
#                                 attribute_category_fr                             suggested_expression  similarity
#                 Autonomie dans l’exécution des tâches                                 de l ’ autonomie    0.909545
#                 Autonomie dans l’exécution des tâches                                être en autonomie    0.887294
#                 Autonomie dans l’exécution des tâches                             agissez en autonomie    0.882306
#                 Autonomie dans l’exécution des tâches                                 de son autonomie    0.881440
#                 Autonomie dans l’exécution des tâches                                tout en autonomie    0.872012
#                                       Bel emplacement                              le milieu recherché    0.766061
#                                       Bel emplacement                              une zone attractive    0.765704
#                                       Bel emplacement                            une région attractive    0.761918
#                                       Bel emplacement                                  la zone plaxage    0.758979
#                                       Bel emplacement                       le quartier incontournable    0.756345
#         Bonne rémunération des heures supplémentaires                       des heures supplémentaires    0.924424
#         Bonne rémunération des heures supplémentaires                       les heures supplémentaires    0.922588
#         Bonne rémunération des heures supplémentaires                       Les heures supplémentaires    0.919093
#         Bonne rémunération des heures supplémentaires                       Des heures supplémentaires    0.899741
#         Bonne rémunération des heures supplémentaires                        les heures supplémentaire    0.891968
#                       Bonnes perspectives de carrière                  les évolutions professionnelles    0.863707
#                       Bonnes perspectives de carrière                  des évolutions professionnelles    0.859831
#                       Bonnes perspectives de carrière                           une carrière évolutive    0.853999
#                       Bonnes perspectives de carrière                           Une carrière évolutive    0.851299
#                       Bonnes perspectives de carrière                  Des évolutions professionnelles    0.850420
#                                        Bons collègues                       des équipes collaborateurs    0.863175
#                                        Bons collègues                         des collègues passionnés    0.862343
#                                        Bons collègues                            une équipe conviviale    0.857006
#                                        Bons collègues                       des collègues sympathiques    0.854486
#                                        Bons collègues                             une équipe convivale    0.850791
#                                   Chalet d’entreprise                              le logement pérenne    0.821796
#                                   Chalet d’entreprise                              un logement pérenne    0.794578
#                                   Chalet d’entreprise                              une résidence ehpad    0.790251
#                                   Chalet d’entreprise                          une société immobilière    0.776265
#                                   Chalet d’entreprise                                  de la résidence    0.761936
#              Choix entre temps plein et temps partiel                           temps plein ou partiel    0.955048
#              Choix entre temps plein et temps partiel                          temps pleins ou partiel    0.947394
#              Choix entre temps plein et temps partiel                         temps complet ou partiel    0.930391
#              Choix entre temps plein et temps partiel                         temps partiel ou complet    0.926057
#              Choix entre temps plein et temps partiel                      un temps complet ou partiel    0.909971
#                                       Chèques vacance                                 la vacance subie    0.679367
#                                       Chèques vacance                                une prime vacance    0.678573
#                                       Chèques vacance                                  suite à vacance    0.643535
#                                       Chèques vacance                           la vacance commerciale    0.610892
#                                       Chèques vacance                                  - Prime vacance    0.478450
#                              Congés flexibles/étendus                                 des jours fériés    0.849714
#                              Congés flexibles/étendus                                 les jours fériés    0.838034
#                              Congés flexibles/étendus                                 Les jours fériés    0.829034
#                              Congés flexibles/étendus                              un congé sabbatique    0.823958
#                              Congés flexibles/étendus                                 Suivi des congés    0.817158
#                            Contrat à durée déterminée                            un contrat temporaire    0.920296
#                            Contrat à durée déterminée                           un contrat intérimaire    0.912415
#                            Contrat à durée déterminée                               un contrat période    0.894804
#                            Contrat à durée déterminée                           un durée contractuelle    0.886087
#                            Contrat à durée déterminée                               un contrat interim    0.883127
#                               Contrat à temps partiel                                 le temps partiel    0.857886
#                               Contrat à temps partiel                                  les temps gamme    0.856594
#                               Contrat à temps partiel                                 du temps partiel    0.855614
#                               Contrat à temps partiel                                 les temps gammes    0.854169
#                               Contrat à temps partiel                                  de temps faites    0.847308
#                                 Contrat à temps plein                                   du temps plein    0.981041
#                                 Contrat à temps plein                                   le temps plein    0.979955
#                                 Contrat à temps plein                                 du temps complet    0.974795
#                                 Contrat à temps plein                                   Le temps plein    0.971335
#                                 Contrat à temps plein                               les temps complets    0.970694
#                                   Emplacement central                                  en plein centre    0.871025
#                                   Emplacement central                                la place centrale    0.867686
#                                   Emplacement central                                     le centre d’    0.863691
#                                   Emplacement central                                   le centre aéré    0.860053
#                                   Emplacement central                               une place centrale    0.842115
#                                      Emploi permanent                           emploi d elongue durée    0.816478
#                                      Emploi permanent                               un poste permanent    0.810903
#                                      Emploi permanent                                une poste durable    0.803732
#                                      Emploi permanent                         le recrutement permanent    0.797867
#                                      Emploi permanent                           un durée contractuelle    0.797831
#                                      Emploi sur appel                                Le poste requière    0.856881
#                                      Emploi sur appel                               le poste recherché    0.824686
#                                      Emploi sur appel                              atout pour le poste    0.824533
#                                      Emploi sur appel                           une demande ponctuelle    0.814379
#                                      Emploi sur appel                               êtrePrise de poste    0.812396
#                                     Emploi temporaire                             s travail temporaire    0.859390
#                                     Emploi temporaire                            le travail temporaire    0.854695
#                                     Emploi temporaire                            Le travail temporaire    0.844597
#                                     Emploi temporaire                                un contrat emploi    0.838867
#                                     Emploi temporaire                          contrat parcours emploi    0.816254
#                                  Environnement social                une ambiance favorable au travail    0.857813
#                                  Environnement social                       une ambiance bienveillante    0.850514
#                                  Environnement social                          Une ambiance conviviale    0.833704
#                                  Environnement social                          une ambiance conviviale    0.831027
#                                  Environnement social                               une saine ambiance    0.830531
#                              Espace de bureau partagé                                   un espace Open    0.804579
#                              Espace de bureau partagé                                    un open space    0.795669
#                              Espace de bureau partagé                           un espace collaboratif    0.776052
#                              Espace de bureau partagé                           un espace conciergerie    0.729495
#                              Espace de bureau partagé                           un open space et serez    0.727826
# Exemption des réglementations sur le temps de travail                              un poste managérial    0.844715
# Exemption des réglementations sur le temps de travail                      le responsable coordinateur    0.823906
# Exemption des réglementations sur le temps de travail                     un responsable départemental    0.818571
# Exemption des réglementations sur le temps de travail                           la menuisierieun poste    0.809251
# Exemption des réglementations sur le temps de travail                          le responsable exécutif    0.807289
#                           Formation en cours d’emploi                          une formation menuisier    0.918290
#                           Formation en cours d’emploi                             une formation solier    0.913960
#                           Formation en cours d’emploi                                  de la formation    0.911408
#                           Formation en cours d’emploi                                 d' une formation    0.911196
#                           Formation en cours d’emploi                         formation soit menuisier    0.911166
#                       Heures supplémentaires requises                  heures travaillées intérimaires    0.892499
#                       Heures supplémentaires requises                     Amplitude horaire de travail    0.886146
#                       Heures supplémentaires requises                       des heures complémentaires    0.885112
#                       Heures supplémentaires requises                       des heures supplémentaires    0.884024
#                        Toute autre mention de salaire                     une rémunération déplafonnée    0.864012
#                        Toute autre mention de salaire                       ce qui concerne le salaire    0.863971
#                        Toute autre mention de salaire                             La rémunération brut    0.862704
#                   Travail impliquant des déplacements                       les déplacements inhérents    0.875866
#                   Travail impliquant des déplacements                    les déplacements occasionnels    0.844291
#                   Travail impliquant des déplacements                    des déplacements occasionnels    0.827862
#                   Travail impliquant des déplacements                       les déplacements ponctuels    0.824119
#                   Travail impliquant des déplacements                       des déplacements ponctuels    0.822845
#                         Travail le week-end/soir/nuit                         les dimanches travaillés    0.826522
#                         Travail le week-end/soir/nuit                             travail midi et soir    0.819627
#                         Travail le week-end/soir/nuit                            le travail le weekend    0.817842
#                         Travail le week-end/soir/nuit                          Le travail hebdomadaire    0.813274
#                         Travail le week-end/soir/nuit                             les jours travaillés    0.808430
#                                    Travail par postes                        Horaires fixes de travail    0.825788
#                                    Travail par postes                     Amplitude horaire de travail    0.820997
#                                    Travail par postes                      poste Effectuer des travaux    0.810976
#                                    Travail par postes                             le travail routinier    0.809755
#                                    Travail par postes                      pourboire Rythme de travail    0.805547
#                                  Tâches intéressantes                              un métier stimulant    0.799970
#                                  Tâches intéressantes                            un métier passionnant    0.762316
#                                  Tâches intéressantes                            un atout enrichissant    0.760665
#                                  Tâches intéressantes                                 en le valorisant    0.753404
#                                  Tâches intéressantes                               un poste stimulant    0.752056
#                                    Tâches stimulantes                                 fort d'une envie    0.779967
#                                    Tâches stimulantes                               la prestation haut    0.757710
#                                    Tâches stimulantes                                   fort en termes    0.755050
#                                    Tâches stimulantes                            des enjeux importants    0.753773
#                                    Tâches stimulantes                               les enjeux majeurs    0.752334
#                                    Variété des tâches                          des tâches diversifiées    0.899773
#                                    Variété des tâches                          les tâches diversifiées    0.898100
#                                    Variété des tâches                        des missions diversifiées    0.882208
#                                    Variété des tâches                                 de divers tâches    0.879552
#                                    Variété des tâches                             des missions variées    0.876002
#                                  Véhicule de fonction                         la fourniture automobile    0.898232
#                                  Véhicule de fonction                            le domaine automobile    0.887816
#                                  Véhicule de fonction                                    le véhicule ·    0.886580
#                                  Véhicule de fonction                            la filière automobile    0.883764
#                                  Véhicule de fonction                            la branche automobile    0.876349

# %%
## We extract this outcome with all expressions retained 
# word_embedding = project_root / "data" / "word_embedding_expressions.xlsx"
# results_df.to_excel(word_embedding)

# ----------------------------------------
# We manually selected relevant expressions (=1 in the added "keep" column, 0 otherwise)
# We need to reimport this excel and continue our worklow with it 
# --> First we lemmatize and clean those new expressions with the cleaning function
# --> We check if there are useless words that we could add in the stop list
# --> we take unique lemmatized expressions and add them (with their row version) in the 
#     attribute base if they do not already exist
# ----------------------------------------

# Re-Load updated dataset
new_expr = pd.read_excel(word_embedding)

# Select relevant potential expressions
new_expr = new_expr[new_expr["keep"]==1]


# ----------------------------------------
# 9.1 Build French stop-word set
# ----------------------------------------
# base NLTK list
french_stopwords = set(stopwords.words('french'))

# extra in-between tokens
additional_stopwords = [
    'alors', 'assez', 'avoir', 'cahier', 'connaissance',
    'directement', 'essentiellement', 'ensuite', 'egalemer',
    'egalement', 'integralement', 'notamment', 'parfaitement',
    'particulieremer', 'plus', 'principalement', 'prioritairement',
    'progressivement', 'progressivemer', 'rapidement',
    'aussi', 'ainsi', 'donc', 'constant', 'continues', 'prevue',
    'prevues', 'possibles', 'possible', 'sont', 'individualisee',
    'soutien', 'personnalise', 'veritable', 'tres',
    'tre', 'veritabl', 'extremement', 'futur', 'tous', 'quelques', 
    'uniquement'
]

french_stopwords |= set(additional_stopwords)


# ----------------------------------------
# 9.2 Cleaning + stop-word removal
# ----------------------------------------
def clean_and_remove_stopwords(text: str) -> str:
    """
    1) Drop URLs, lowercase
    2) Strip accents via unicodedata
    3) Keep only letters & spaces
    4) Collapse whitespace
    5) Remove French stop-words
    """
    # 1) URLs + lowercase
    s = re.sub(r'http\S+|www\.\S+', ' ', text).lower()
    # 2) strip accents
    s = unicodedata.normalize('NFD', s)
    s = ''.join(ch for ch in s if not unicodedata.combining(ch))
    # 3) keep only letters & spaces
    s = re.sub(r'[^a-z\s]', ' ', s)
    # 4) collapse whitespace
    s = re.sub(r'\s+', ' ', s).strip()
    # 5) remove stop-words
    tokens = [tok for tok in s.split() if tok not in french_stopwords]
    return ' '.join(tokens)


# ----------------------------------------
# 9.3 Apply to your filtered expressions
# ----------------------------------------
# assume new_expr has already been read and filtered (keep==1)
new_expr['lemma'] = new_expr['suggested_expression'] \
                       .astype(str) \
                       .apply(clean_and_remove_stopwords)


# ----------------------------------------
# 9.4 Apply to filtered expressions 
# ----------------------------------------

# Drop rows with duplicated lemma
new_expr.drop_duplicates(subset=["lemma"], inplace=True)

# Raname expression column
new_expr.rename(columns={"suggested_expression": "expression"}, inplace=True)

# Select important columns
new_expr = new_expr.loc[:, ["attribute_category_fr", "expression"]]


# ----------------------------------------
# 9.5 Append new expressions to main database
# ----------------------------------------

# Re-upload the main attribute base excel
attribute_base = pd.read_excel(attribute_file)

# 1) Prepare `new_expr` with the same columns as `attribute_base`
new_rows = new_expr.assign(aggregate_category_fr=pd.NA, _is_new=True)


# 2) Tag the originals so they sort before the new ones
orig = attribute_base.copy().assign(_is_new=False)

# 3) Concatenate, sort, and forward-fill
merged = (
    pd.concat([orig, new_rows], ignore_index=True)
      .sort_values(["attribute_category_fr", "_is_new"])
      .assign(
         aggregate_category_fr=lambda df: df
           .groupby("attribute_category_fr")["aggregate_category_fr"]
           .ffill()
      )
      .drop(columns="_is_new")
      .reset_index(drop=True)
)

attribute_base = merged

# ----------------------------------------
# 9.6 Deduplicate similar lemma from the full attribute base
# ----------------------------------------

# Assume new_expr has already been read and filtered (keep==1)
attribute_base['lemma'] = attribute_base['expression'].astype(str).apply(clean_and_remove_stopwords)

# Drop rows with duplicated lemma
attribute_base.drop_duplicates(subset=["lemma"], inplace=True)


# ----------------------------------------
# Export
# ----------------------------------------
# attribute_base.to_excel(output_file, index=False)
