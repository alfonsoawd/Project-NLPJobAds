# %% [markdown]
# # 📊 Job Descriptions Topic Modeling Pipeline
#
# An end-to-end Jupyter notebook that applies LDA topic modeling to a corpus of French job ads in order to surface novel, category-specific expressions (amenities) directly from the data. These discovered terms are used to enrich our attribute database, which will then drive scalable attribute scraping across the full dataset.

# %%
# ============================================================================
# STEP 1: IMPORTS & PROJECT PATHS
# ============================================================================

# Standard Library
import csv
import os
import random
import re
import unicodedata
from collections import defaultdict
from pathlib import Path

# Data Manipulation
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Natural Language Processing (NLP)
import nltk
from nltk.corpus import stopwords
import spacy
from bs4 import BeautifulSoup
from spacy.matcher import Matcher

# Topic Modeling
from gensim import corpora
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel

# Utilities
from unidecode import unidecode


# Define project directories
project_root = Path().resolve().parent
jocas_dir = "/Users/alfonso/Desktop/JOCAS"  # adjust if needed
file = project_root / "data" / "attribute_base_processed.xlsx"

# %%
# ============================================================================
# STEP 2: INGEST CSVs & BASIC FILTERING
# ============================================================================

# -------------------------------
# Initialize container
# -------------------------------
jocas_list = []

# -------------------------------
# Walk though source folders
# -------------------------------
for source_folder in os.listdir(jocas_dir):
    source_path = os.path.join(jocas_dir, source_folder)
    
    if os.path.isdir(source_path):
        # -------------------------------
        # Collect all csv files under this source
        # -------------------------------
        csv_files = []
        
        # Walk through all subdirectories (e.g., "January", "December", etc.)
        for root, dirs, files in os.walk(source_path):
            for file in files:
                # Case-insensitive check for .csv files
                if file.lower().endswith('.csv'):
                    csv_files.append(os.path.join(root, file))
        
        print(f"Found {len(csv_files)} CSV files in source folder: {source_folder}")
        
        if not csv_files:
            continue
        
        # -------------------------------
        # Select up to 50 csv files from this source
        # -------------------------------
        if len(csv_files) > 50:
            selected_files = random.sample(csv_files, 50)
        else:
            selected_files = csv_files
        
        print(f"Processing {len(selected_files)} files from source folder: {source_folder}")
        
        # Process each selected CSV file
        for file_path in selected_files:
            try:
                df = pd.read_csv(
                    file_path,
                    header=0,
                    sep=';',
                    on_bad_lines='skip',
                    low_memory=False,
                    quoting=csv.QUOTE_MINIMAL,
                    escapechar='\\'
                )
                jocas_list.append(df)
            except Exception as e:
                print(f"Failed to read {file_path}: {e}")

        print(f"Finished processing source folder: {source_folder}")

# -------------------------------
# Aggregate all dataframes into one
# -------------------------------
df_job = pd.concat(jocas_list, ignore_index=True)

# -------------------------------
# Flag English text and word counts
# -------------------------------
pd.set_option('display.max_colwidth', None)
def is_english(txt, threshold=2):
    common = ['the','and','for','with','that','this','from']
    return sum(bool(re.search(rf'\b{w}\b', txt, re.I)) for w in common) >= threshold

df_job['description_full'] = df_job['description_full'].astype(str)
df_job['word_count']      = df_job['description_full'].str.split().str.len()
df_job['is_english']      = df_job['description_full'].apply(is_english)

# %%
# ============================================================================
# STEP 3: PREPROCESSING FOR TOPIC MODELLING
# ============================================================================

# ------------------------------------------------------------------------------
# SETUP
# ------------------------------------------------------------------------------
# Download NLTK stopwords if needed
nltk.download('stopwords')
french_stopwords = set(stopwords.words('french'))

# Load (or download) spaCy French model without parser & NER for speed
try:
    nlp = spacy.load("fr_core_news_sm", disable=["parser", "ner"])
except OSError:
    import spacy.cli
    spacy.cli.download("fr_core_news_sm")
    nlp = spacy.load("fr_core_news_sm", disable=["parser", "ner"])

# ------------------------------------------------------------------------------
# STEP 3.0: SAMPLE JOB DESCRIPTIONS
# ------------------------------------------------------------------------------
df_sample = (
    df_job
    .sample(n=100000, random_state=42)
    .copy()
)
df_sample['description_full'] = df_sample['description_full'].astype(str)
df_sample.dropna(subset=['description_full'], inplace=True)

# ------------------------------------------------------------------------------
# STEP 3.1: TEXT CLEANING & LEMMATIZATION
# ------------------------------------------------------------------------------
def clean_text(text, remove_accents=True):
    """Strip HTML, URLs, lowercase, remove accents, keep only letters/spaces."""
    # Remove HTML
    soup = BeautifulSoup(text, "html.parser")
    text = soup.get_text(separator=" ")
    # Drop URLs
    text = re.sub(r'http\S+|www\.\S+', ' ', text)
    text = text.lower()
    # Normalize accents
    if remove_accents:
        text = unicodedata.normalize('NFD', text)
        text = text.encode('ascii', 'ignore').decode('utf-8')
    # Keep only letters & spaces
    pattern = r'[^a-z\s]' if remove_accents else r'[^a-zàâçéèêëîïôûùüÿñæœ\s]'
    text = re.sub(pattern, ' ', text)
    # Collapse whitespace
    return re.sub(r'\s+', ' ', text).strip()

def tokenize_lemmatize(text):
    """Return lemmas longer than 2 chars, alphabetic & not in French stopwords."""
    doc = nlp(text)
    return [
        tok.lemma_.lower()
        for tok in doc
        if tok.is_alpha
           and len(tok.lemma_) > 2
           and tok.lemma_.lower() not in french_stopwords
    ]

# Apply cleaning and tokenization
df_sample['clean'] = df_sample['description_full'].apply(lambda x: clean_text(x))
df_sample['tokens'] = df_sample['clean'].apply(tokenize_lemmatize)
df_sample = df_sample[df_sample['tokens'].map(len) > 0]

# ------------------------------------------------------------------------------
# STEP 3.2: BUILD BIGRAMS & TRIGRAMS
# ------------------------------------------------------------------------------
all_tokens = df_sample['tokens'].tolist()

# Train phrase models
bigram = Phrases(all_tokens, min_count=5, threshold=10)
trigram = Phrases(bigram[all_tokens], threshold=10)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)

def make_ngrams(tokens):
    """Merge tokens into bigrams & trigrams (underscore-joined)."""
    bigr = bigram_mod[tokens]
    trigr = trigram_mod[bigr]
    # Return only tokens that are true multi-word phrases
    return [t for t in bigr if '_' in t] + [t for t in trigr if '_' in t]

# Apply n-gram extraction and filter empties
df_sample['tokens_final'] = df_sample['tokens'].apply(make_ngrams)
df_sample = df_sample[df_sample['tokens_final'].map(len) > 0]

# ------------------------------------------------------------------------------
# STEP 3.3: DICTIONARY + CORPUS + FILTERING
# ------------------------------------------------------------------------------
# 3.3.1 Create Gensim Dictionary
dictionary = corpora.Dictionary(df_sample['tokens_final'])

# 3.3.2 Filter out rare and frequent tokens
dictionary.filter_extremes(
    no_below=5,      # keep tokens present in at least 5 docs
    no_above=0.5,    # keep tokens in at most 50% of docs
    keep_n=100000   # keep top 100k tokens by frequency
)

# 3.3.3 Build Corpus (Bag-of-Words for each doc)
corpus = [dictionary.doc2bow(doc) for doc in df_sample['tokens_final']]

# ------------------------------------------------------------------------------
# ─── SAVE FOR FUTURE USE ───────────────────────────────────────────────────────
# 1) Save the dictionary
# dictionary.save('job_dict.dict')  
#    → writes a .dict file you can later load with corpora.Dictionary.load()
#
# 2) Serialize the corpus to Matrix Market format
# corpora.MmCorpus.serialize('job_corpus.mm', corpus)
#    → writes a .mm file and an associated .mm.index file
# ------------------------------------------------------------------------------
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alfonso/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /var/folders/5z/n4wfh12s55d5j381j6gl47c40000gn/T/ipykernel_22386/3967760488.py:47: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, "html.parser")

# %%
# ------------------------------------------------------------------------------
# STEP 4: TRAIN LDA & COMPUTE COHERENCE
# ------------------------------------------------------------------------------

# ------------------------------------------------------------------------------
# STEP 4.1: TRAIN LDA WITH DIFFERENT TOPIC NUMBER + COHERENCE PLOT
# ------------------------------------------------------------------------------

def compute_coherence_values(
    dictionary,
    corpus,
    texts,
    start=5,
    limit=50,
    step=5,
    passes=15,
    alpha='auto'
):
    """
    Compute c_v coherence for various numbers of topics.

    Parameters:
    -----------
    dictionary : Gensim Dictionary object
    corpus     : Gensim Corpus (bag-of-words)
    texts      : List of token lists (e.g., df_sample['tokens_final'])
    start      : Minimum number of topics to try
    limit      : Maximum number of topics to try
    step       : Increment between topic counts
    passes     : Number of passes through the corpus during training
    alpha      : Dirichlet prior for document-topic distribution
    """
    model_list = []
    coherence_values = []

    for num_topics in range(start, limit + 1, step):
        # 4.1.1 Train LDA model
        model = LdaModel(
            corpus=corpus,
            id2word=dictionary,
            num_topics=num_topics,
            random_state=42,
            passes=passes,
            alpha=alpha,
            per_word_topics=False
        )
        model_list.append(model)

        # 4.1.2 Compute coherence
        coherencemodel = CoherenceModel(
            model=model,
            texts=texts,
            dictionary=dictionary,
            coherence='c_v'
        )
        coh = coherencemodel.get_coherence()
        coherence_values.append(coh)
        print(f"Trained LDA with {num_topics} topics — coherence = {coh:.4f}")

    return model_list, coherence_values

# --- USAGE: explore coherence across topic counts ---
start, limit, step = 15, 25, 1
models, coherences = compute_coherence_values(
    dictionary=dictionary,
    corpus=corpus,
    texts=df_sample['tokens_final'],
    start=start,
    limit=limit,
    step=step,
    passes=15,
    alpha='auto'
)

# 4.1.3 Plot coherence scores
x = list(range(start, limit + 1, step))
plt.figure(figsize=(8, 4))
plt.plot(x, coherences, marker='o')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence (c_v)")
plt.title("Coherence vs. Number of Topics")
plt.tight_layout()
plt.show()

# 4.1.4 Select best model
best_idx = coherences.index(max(coherences))
best_num_topics = x[best_idx]
best_model = models[best_idx]
print(f"\nOptimal number of topics: {best_num_topics} (c_v = {coherences[best_idx]:.4f})")



# ------------------------------------------------------------------------------
# STEP 4.2: TRAIN LDA WITH USER-DEFINED TOPIC COUNT
# ------------------------------------------------------------------------------
# Adjust these as needed:
num_topics = 19
passes     = 15
alpha      = 'auto'

lda_model = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    random_state=42,
    passes=passes,
    alpha=alpha,
    per_word_topics=True
)



# ------------------------------------------------------------------------------
# STEP 4.3: SAVE & VISUALIZE
# ------------------------------------------------------------------------------
# 4.3.1 Prepare visualization
vis = gensimvis.prepare(lda_model, corpus, dictionary)

# 4.3.2 Save to HTML
pyLDAvis.save_html(vis, f"lda_{num_topics}topics_vis.html")
print(f"Saved LDA model visualization: lda_{num_topics}topics_vis.html")
# Out:
# Trained LDA with 15 topics, coherence=0.4935
# Trained LDA with 16 topics, coherence=0.5441
# Trained LDA with 17 topics, coherence=0.5270
# Trained LDA with 18 topics, coherence=0.5288
# Trained LDA with 19 topics, coherence=0.5470
# Trained LDA with 20 topics, coherence=0.5460
# Trained LDA with 21 topics, coherence=0.5196
# Trained LDA with 22 topics, coherence=0.5271
# Trained LDA with 23 topics, coherence=0.4805
# Trained LDA with 24 topics, coherence=0.4964
# Trained LDA with 25 topics, coherence=0.5121
# Optimal number of topics: 19 (c_v=0.5470)

# %%
# ------------------------------------------------------------------------------
# STEP 5: BUILD DATAFRAME WITH MOST COMMON EXPRESSIONS IN TOPICS
# ------------------------------------------------------------------------------
records = []
for topic_id in range(num_topics):
    # lda_model.show_topic returns [(word, weight), …] sorted by descending weight
    for rank, (word, weight) in enumerate(
            lda_model.show_topic(topic_id, topn=50),
            start=1
        ):
        records.append({
            'topic':  topic_id,
            'rank':   rank,
            'word':   word,
            'weight': weight
        })

# Create DataFrame of top-50 words per topic
df_top50 = pd.DataFrame(records)

# ─── SAVE FOR FUTURE USE ───────────────────────────────────────────────────────
# df_top50.to_csv('top50_words_per_topic_long.csv', index=False)

#--------------------------
# Looking at the dataframe manually, we extract expressions that
# appear as attributes (amenities...) for the next step
#--------------------------

# ------------------------------------------------------------------------------
# STEP 6: EXTRACT KEYWORD VARIANTS WITH spaCy
# ------------------------------------------------------------------------------
# 6.1 Load French model (disable unneeded components for speed)
nlp_matcher = spacy.load(
    "fr_core_news_sm",
    disable=["parser", "ner", "textcat"]
)

# 6.2 Define underscore-joined keywords
keywords = [
    "collaborateur_passionne", "ambiance_travail", "declaration_social",
    "plan_epargne", "etre_force_proposition", "force_proposition",
    "prendre_initiative", "total_autonomie", "sans_responsable",
    "autonomie_rigueur", "chef_projet", "grand_compte", "prise_decision",
    "prendre_charge", "voir_confier", "permettre_epanouir", "haut_niveau",
    "ete_passionn", "innovation_passion", "deplacement_ponctuel",
    "deplacement_occasionnel", "mission_variee", "bien_etre",
    "contrat_cdi", "cdd_cdi", "temps_partiel", "temps_complet",
    "temps_plein", "week_end", "fort_croissance", "opportunite_carriere",
    "faire_progresser", "montee_grade", "possibilite_evoluer",
    "evolution_carriere", "montee_competence", "amelioration_continuer",
    "devenir_expert", "conseil_carriere", "formation_tout_long",
    "brut_annuel", "remuneration_brut", "euro_brut", "remuneration_avantage",
    "remuneration_attractif", "convention_collectif", "salair_fixe",
    "pourvoir_possible_remuneration", "remuneration_selon", "salair_selon",
    "mois_prime", "taux_horaire", "minimum_garanti", "souhait_prime",
    "prime_collectif", "salaire_brut", "brut_mensuel", "annuel_brut",
    "maison_individuel", "ticket_restaurant", "frais_deplacement",
    "cheque_vacance", "conge_paye",
]

# 6.3 Initialize the Matcher
matcher = Matcher(nlp_matcher.vocab)
max_span = 6  # maximum tokens in a matched span

for kw in keywords:
    parts = kw.split("_")
    if len(parts) == 1:
        # single-lemma keyword
        pattern = [{"LEMMA": parts[0]}]
    else:
        # allow any alpha tokens between first and last lemma
        pattern = [
            {"LEMMA": parts[0]},
            {"IS_ALPHA": True, "OP": "*"},
            {"LEMMA": parts[-1]}
        ]
    matcher.add(kw, [pattern])

# 6.4 Run matcher over all job descriptions
variants = defaultdict(set)
for doc in nlp_matcher.pipe(df_sample['description_full'].tolist(),
                             batch_size=32, n_process=2):
    for match_id, start, end in matcher(doc):
        if end - start <= max_span:
            key = nlp_matcher.vocab.strings[match_id]
            variants[key].add(doc[start:end].text)

# 6.5 Convert sets to lists and display
variants = {k: list(v) for k, v in variants.items()}
for kw, forms in variants.items():
    print(f"\n=== {kw} ({len(forms)} variants) ===")
    for form in forms:
        print(" •", form)
# Out:
# === ticket_restaurant (15 variants) ===
#  • tickets restaurants
#  • Tickets restos
#  • ticket restaurants
#  • tickets restaurant
#  • tickets resto
#  • tickets Restaurant
#  • ticket restaurant
#  • Tickets restau
#  • Tickets resto
#  • Tickets Restaurant
#  • Tickets restaurant
#  • TICKETS RESTAURANT
#  • Tickets Restaurants
#  • tickets restaurant et restaurants
#  • Tickets restaurants
#
# === prendre_charge (75 variants) ===
#  • pris en charge
#  • prenant plus particulièrement en charge
#  • prenaient en charge
#  • prenez assez rapidement en charge
#  • prenez plus particulièrement en charge
#  • prendrez aussi en charge
#  • prennent en charge
#  • prendre en charges
#  • prenez également en charge
#  • prenez un charge
#  • prenez directement en charge
#  • prendrez intégralement en charge
#  • Prendre en charge
#  • prendrez en charge
#  • prend en charge
#  • prises en charge
#  • prenez ainsi en charge
#  • prenez aussi en charge
#  • prend à sa charge
#  • prenez à votre charge
#  • prenez en en charge
#  • Prendre le charge
#  • prendra techniquement en charge
#  • Prendre à sa charge
#  • prenez en charge
#  • prend également en charge
#  • prendra aussi en charge
#  • pris en charges
#  • Prend en charge
#  • prenez alors en charge
#  • prise en charge
#  • prenez donc en charge
#  • prendrez principalement en charge
#  • prendre temporairement en charge
#  • Prendre charge
#  • PRENDRE EN CHARGE
#  • prendrez alors en charge
#  • prendrez notamment en charge
#  • prenez en charges
#  • prendrez donc en charge
#  • prenez notamment en charge
#  • prend plus particulièrement en charge
#  • prenez ensuite en charge
#  • prendrez essentiellement en charge
#  • prenez à la fois en charge
#  • prendrez prioritairement en charge
#  • pris à notre charge
#  • prenons en charge
#  • prit en charge
#  • prendre rapidement en charge
#  • Prendre également en charge
#  • prendra en charge
#  • Prendre progressivement en charge
#  • prendre en charge
#  • prenez charge
#  • Prendre connaissance du cahier des charges
#  • prises en charges
#  • prendra préférentiellement en charge
#  • prennent bien sûr en charge
#  • prenez progressivement en charge
#  • Pris en charge
#  • prendre la charge
#  • prendrez également en charge
#  • prenez rapidement en charge
#  • prendrez à charge
#  • Prendre la charge
#  • prendriez également en charge
#  • prenne en charge
#  • prendre progressivement en charge
#  • prendrez directement en charge
#  • prenant en charge
#  • pris à charge
#  • PRENEZ EN CHARGE
#  • Prenez en charge
#  • prendrez progressivement en charge
#
# === grand_compte (22 variants) ===
#  • grands Comptes
#  • Grands et Moyens Comptes
#  • grand comptes
#  • grand livre et justifications des comptes
#  • GRAND COMPTE
#  • GRANDS COMPTES
#  • grand compte
#  • grands compte
#  • Grand Compte
#  • grands livres et balances des comptes
#  • Grands Comptes et Comptes
#  • Grand compte
#  • grandes comptes
#  • Grand Comptes
#  • grande ampleur pour le compte
#  • Grands Comptes et très Grands Comptes
#  • GRAND DÉPLACEMENT pour le compte
#  • Grands Comptes
#  • Grands Compte
#  • grands volumes pour de grands comptes
#  • grands comptes
#  • Grands comptes
#
# === sans_responsable (3 variants) ===
#  • sans accident responsable
#  • sans responsable
#  • sans équivalence Rattaché au Responsable
#
# === taux_horaire (10 variants) ===
#  • Taux Horaire
#  • Taux brut horaire
#  • Taux Horaires
#  • taux normal Taux horaire
#  • taux horaire complète le taux horaire
#  • taux horaire
#  • Taux horaires
#  • taux horaires
#  • Taux horaire
#  • TAUX HORAIRE
#
# === temps_partiel (48 variants) ===
#  • TEMPS PARTIELS
#  • temps plein et à temps partiel
#  • Temps plein et temps partiel
#  • Temps complet ou partiel
#  • temps complet ou à temps partiel
#  • temps plein à temps partiel
#  • temps ou à temps partiel
#  • temps complet et un temps partiel
#  • temps plein soit à temps partiel
#  • temps de travail à temps partiel
#  • temps pleins ou des temps partiels
#  • temps complet ou temps partiel
#  • Temps partiels
#  • Temps de travail partiel
#  • Temps complet ou Temps partiel
#  • temps plein ou le temps partiel
#  • Temps plein ou temps partiel
#  • TEMPS PLEIN OU TEMPS PARTIEL
#  • temps complet ou partiel
#  • temps plein ou à temps partiel
#  • Temps complet ou temps partiel
#  • Temps plein ou à temps partiel
#  • temps plein et partiel
#  • temps plein ou en temps partiel
#  • TEMPS PARTIEL
#  • temps plein ou à partiel
#  • temps plein ou temps partiel
#  • temps plein mais Temps partiel
#  • temps plein ou un temps partiel
#  • temps plein et temps partiel
#  • TEMPS PLEIN ou PARTIEL
#  • temps ou partiel
#  • temps pleinou temps partiel
#  • temps partielle
#  • temps complet ou un temps partiel
#  • temps partiel ou temps partiel
#  • temps partiels
#  • temps ou temps partiel
#  • Temps partiel
#  • temps plein ou partiel
#  • temps complet et temps partiel
#  • Temps plein ou partiel
#  • temps complet ou en temps partiel
#  • temps partiel
#  • Temps de travail Temps partiel
#  • Temps plein ou Temps partiel
#  • temps et à temps partiel
#  • TEMPS COMPLET OU TEMPS PARTIEL
#
# === ambiance_travail (14 variants) ===
#  • Ambiance de travail
#  • ambiance favorable au travail
#  • ambiance de travail
#  • ambiance stimulante de travail
#  • ambiance et condition de travail
#  • ambiance et reconnaissance dans le travail
#  • ambiance au travail
#  • ambiance et des conditions de travail
#  • Ambiance et cadre de travail
#  • ambiance agréable et travail
#  • ambiance et les conditions du travail
#  • ambiance alliant travail
#  • ambiances de travail
#  • ambiance et un cadre de travail
#
# === temps_plein (30 variants) ===
#  • Temps partiel ou Temps plein
#  • temps de travail à temps plein
#  • temps partiel à temps plein
#  • temps partiel ou à temps plein
#  • temps plein
#  • temps Plein
#  • temps pleins
#  • Temps partiel évolutif Temps plein
#  • temps partiel à temps pleins
#  • temps partiel ou plein
#  • temps pleiN
#  • temps partiel ou temps plein
#  • temps partiel et temps plein
#  • Temps partiel ou plein
#  • temps partiel évolutif temps plein
#  • TEMPS PLEINEn plein
#  • Temps Plein
#  • Temps de travail Temps plein
#  • temps partiel évolutif en temps plein
#  • temps choisi ou à temps plein
#  • Temps plein
#  • temps partiel pouvant évoluer en plein
#  • temps partiel évolutif à temps plein
#  • Temps partiel ou temps plein
#  • temps partiel ou un temps plein
#  • TEMPS PLEIN
#  • Temps pleins
#  • temps plein ou dentiste temps plein
#  • temps complet occupé à temps plein
#  • TEMPS DE TRAVAIL Temps plein
#
# === convention_collectif (7 variants) ===
#  • conventions collectives
#  • Convention Collective
#  • Convention collective
#  • convention Collective
#  • Conventions Collectives
#  • Conventions collectives
#  • convention collective
#
# === fort_croissance (20 variants) ===
#  • Fort de notre croissance
#  • fortes croissances
#  • fortes croissance
#  • forte ambition de croissance
#  • forte dynamique de croissance
#  • Fort de cette hyper croissance
#  • Fort de sa croissance
#  • fortes ambitions de croissance
#  • forte et connaît une croissance
#  • forte politique de croissance
#  • forte de croissance
#  • forte stratégie de croissance
#  • fort niveau de croissance
#  • forte de sa croissance
#  • fort potentiel de croissance
#  • fortes de croissance
#  • Forte croissance
#  • fortes perspectives de croissance
#  • forte croissance
#  • fort développement avec une croissance
#
# === chef_projet (42 variants) ===
#  • Chefs de Projets
#  • Chefs de projet
#  • CHEF DE PROJET
#  • Chef Projet
#  • Chef De Projets
#  • Chef de Projet
#  • chef de projets
#  • chefs et directeurs de projets
#  • Chef de Chantier sur des projets
#  • chef projet
#  • chef de Projets
#  • chef de projet pilotera des projets
#  • chef de projet
#  • chefs de projets Participer aux projets
#  • chef OR de OR projet
#  • Chef de projet pour des projets
#  • chef de projet sur des projets
#  • Chef de Projet sur les projets
#  • Chef de projets
#  • CHEF de PROJET
#  • Chefs de projets
#  • chef de projet confirmé projets
#  • Chef de Chantier Grands Projets
#  • chefs projet
#  • Chefs de projets en phase projet
#  • CHEF OU CHARGE DE PROJETS
#  • Chef de projet Projets
#  • chefs et directeurs de projet
#  • Chef de Projets
#  • CHEF de PROJETS
#  • chefs de projet
#  • Chef de projet anime le projet
#  • Chef projet
#  • Chef de Projet pour leurs projets
#  • chefs de Projets
#  • chefs de projets
#  • CHEF DE PROJETS
#  • Chef de Chantier en Grands Projets
#  • Chef de projet
#  • Chef de Groupe Installations Electriques Projets
#  • chef ou la cheffe de projets
#  • Chefs et Responsables de projets
#
# === minimum_garanti (5 variants) ===
#  • minimum rémunéré garanti
#  • minimum indicatif est garanti
#  • minimums garantis
#  • minimum garanti
#  • minimum mensuel garanti
#
# === force_proposition (18 variants) ===
#  • Force e proposition
#  • forces de proposition
#  • Force proposition
#  • force de conviction et de proposition
#  • forces de propositions
#  • force de conseil et de propositions
#  • Force de proposition
#  • Force de conviction et de proposition
#  • Force de Proposition
#  • force de propositions
#  • force de conseil et de proposition
#  • force proposition
#  • force de proposition
#  • Force de conseils et de propositions
#  • force de pRoposition
#  • Force de propositions
#  • force constante de propositions
#  • FORCE DE PROPOSITION
#
# === brut_annuel (11 variants) ===
#  • brute annuelle
#  • bruts annuels
#  • bruts annuel
#  • brut fixe annuel
#  • brut Mensuel Salaire annuel
#  • brut mensuel et un variable annuel
#  • Brut annuel
#  • brut annuel
#  • brute annuel
#  • brut annuelle
#  • brut annuels
#
# === haut_niveau (9 variants) ===
#  • Haut niveau
#  • HAUT NIVEAU
#  • haut niveaux
#  • Haut Niveau
#  • hauts niveau
#  • haut de gamme Mode et niveau
#  • haut niveau avec un niveau
#  • hauts niveaux
#  • haut niveau
#
# === contrat_cdi (31 variants) ===
#  • Contrat intérim puis cdd ou cdi
#  • contrat peut déboucher sur un CDI
#  • Contrat en CDI
#  • Contrat évolutif en cdi
#  • contrats en CDI
#  • contrat cdi
#  • Contrat CPS en CDI
#  • Contrat pouvant évoluer vers un CDI
#  • Contrat intérim avec possibilité de CDI
#  • contrat en cdi
#  • Contrat Veuillez sélectionner une valeur CDI
#  • contrat plein temps en CDI
#  • contrat long et de CDI
#  • contrat pouvant être transformé en cdi
#  • Contrat pouvant évoluer sur un CDI
#  • contrat salarié en CDI
#  • CONTRAT CDI
#  • Contrat de travail en CDI
#  • Contrats en CDI
#  • Contrat en vue CDI
#  • contrat est évolutif vers un CDI
#  • contrat Nous vous proposons un CDI
#  • contrat proposé est un CDI
#  • Contrat en cdi
#  • contrat CDI
#  • contrats CDI
#  • contrat salarié CDI
#  • contrat en CDI
#  • contrat est un CDI
#  • contrat de travail en CDI
#  • contrat à durée indeterminée CDI
#
# === euro_brut (23 variants) ===
#  • euros annuels bruts
#  • € annuels bruts
#  • euros annuel brut
#  • € Brut
#  • € de prime de soirée brute
#  • Euros bruts
#  • Euros annuel brut
#  • € mensuelle brut
#  • € annuel brut
#  • euros annuelle brut
#  • € en fixe annuel brut
#  • € bruts
#  • € BRUT
#  • euros annuels brut
#  • € brut
#  • euro bruts
#  • euro brut
#  • € Annuel brut
#  • € mensuel brut
#  • euros bruts
#  • € Prime de polyvalence brut
#  • Euros brut
#  • euros brut
#
# === salaire_brut (19 variants) ===
#  • Salaire fixe brut
#  • salaire brut
#  • Salaire horaire brut
#  • salaire horaire brut
#  • salaire de base mensuel brut
#  • SALAIRE Taux horaire brut
#  • salaire mensuel brut
#  • Salaire affiché brut
#  • salaire indiqué est un montant brut
#  • SALAIRE ET DIVERS Taux horaire brut
#  • Salaire mensuel brut
#  • salaire province mensuel brut
#  • salaire annuel brut
#  • Salaire de base brut
#  • Salaire brut
#  • salaire attractif de brut
#  • Salaire annuel brut
#  • salaire minimum garanti brut
#  • salaire mentionné est brut
#
# === temps_complet (23 variants) ===
#  • temps de travail temps complet
#  • Temps de travail Temps complet
#  • temps en Hospitalisation Complète
#  • temps partiel avec possibilité temps complet
#  • Temps Partiel ou Temps Complet
#  • TEMPS COMPLETS
#  • temps partiel complet
#  • TEMPS COMPLET
#  • Temps choisi ou complet
#  • temps partiel ou complet
#  • temps partiel ou temps complet
#  • temps complet
#  • Temps partiel ou complet
#  • temps complets
#  • Temps non complet
#  • temps non complet
#  • Temps partiel ou temps complet
#  • temps en complète
#  • temps plus complet
#  • Temps complet
#  • Temps Complet
#  • temps partiel et temps complet
#  • temps partiel ou en temps complet
#
# === maison_individuel (10 variants) ===
#  • maisons individuelles
#  • maison individuelles
#  • maisons individuelle
#  • maison individuelle
#  • Maisons Individuelles
#  • Maisons individuelles
#  • Maison individuelle
#  • maisons individuels
#  • MAISON INDIVIDUELLE
#  • MAISONS INDIVIDUELLES
#
# === brut_mensuel (9 variants) ===
#  • brut Mensuel
#  • brut mensuel
#  • brut mensuels
#  • brut de prime mensuelle
#  • bruts mensuels
#  • brute mensuelle
#  • brut mensuelle
#  • bruts mensuel
#  • Brut mensuel
#
# === etre_force_proposition (14 variants) ===
#  • Etre source de propositions
#  • Etre réactif et force de propositions
#  • Etre force constante de propositions
#  • Etre moteur et force de proposition
#  • Etre de force de proposition
#  • Etre Force de proposition
#  • Etre force de propositions
#  • Etre source de proposition
#  • Etre responsable de la proposition
#  • Etre volontaire et force de proposition
#  • Etre créatif et force de proposition
#  • Etre force de proposition
#  • Etre un soutien dans les propositions
#  • Etre acteur et force de proposition
#
# === formation_tout_long (27 variants) ===
#  • Formation professionnelle continue tout au long
#  • formation pour une longue
#  • Formation tout au long
#  • formation continue tout au long
#  • Formations Tout au Long
#  • formation en soutien tout au long
#  • formation longue
#  • formations tout au long
#  • formations tut au long
#  • Formation continue tout au long
#  • formation personnalisé tout au long
#  • formations vous accompagnent tout au long
#  • Formations tout au long
#  • formation individualisées tout au long
#  • formation se feront tout au long
#  • Formation assurée via une intégration longue
#  • formations au long
#  • formation tout au long
#  • formations continues tout au long
#  • formation tout le long
#  • formation prévue tout au long
#  • formation sont possibles tout au long
#  • FORMATIONS TOUT AU LONG
#  • formation de longue
#  • formation à long
#  • formation de qualité tout au long
#  • formations sont prévues tout au long
#
# === prendre_initiative (26 variants) ===
#  • prendre prendre des initiatives
#  • prendre des décisions et des initiatives
#  • prendre des initiative
#  • prend les initiatives
#  • prendre toute décision et initiative
#  • prendre rapidement des initiatives
#  • prenant les initiatives
#  • prendre régulièrement des initiatives
#  • prenant part activement à des initiatives
#  • prend des initiatives
#  • prenez des initiatives
#  • Prend les initiatives
#  • Prend des initiatives
#  • Prendre des initiatives
#  • prenant toute initiative
#  • prenez les initiatives
#  • Prendre les initiatives
#  • prenez des décisions et des initiatives
#  • Prendre toutes les initiatives
#  • prendre des initiatives
#  • prenant des initiatives
#  • prendre part aux initiatives
#  • prenez toutes les initiatives
#  • prendre les initiatives
#  • prendre toutes les initiatives
#  • prendre sans délai les initiatives
#
# === salair_selon (9 variants) ===
#  • salaire varie selon
#  • salaire de base selon
#  • salaire selon
#  • Salaire selon
#  • salaire est à négocier selon
#  • salaire négociable selon
#  • salaire à définir selon
#  • salaire est à déterminer selon
#  • salaire à négocier selon
#
# === prime_collectif (15 variants) ===
#  • prime collective
#  • prime selon convention collective
#  • primes sur objectifs individuels et collectifs
#  • primes collective
#  • primes individuelles et collectives
#  • prime commerciale collective
#  • Primes et indemnités selon convention collective
#  • primes collectives
#  • primes individuelles et primes collectives
#  • primes paniers selon convention collective
#  • primes individuelle et collective
#  • Primes de productivité collective
#  • Primes collectives
#  • Primes collective
#  • Prime collective
#
# === annuel_brut (6 variants) ===
#  • annuels bruts
#  • annuels brut
#  • annuelle brut
#  • annuel brut
#  • annuelle brute
#  • Annuel brut
#
# === voir_confier (17 variants) ===
#  • voir confier
#  • verra confier
#  • voit donc confier
#  • voyez confier
#  • verrait confier
#  • verra confié
#  • verrez confier
#  • voit confier
#  • verrez alors confier
#  • voir confié
#  • verra rapidement confier
#  • vu confier
#  • voyant confier
#  • verrez confier confier
#  • voir rapidement confier
#  • verrez confié
#  • voient confiées
#
# === faire_progresser (19 variants) ===
#  • faire et de les faire progresser
#  • faire progresser
#  • feront progresser
#  • faire carrière et progresser
#  • FAIRE PROGRESSER
#  • ferez grandir et progresser
#  • Fait progresser
#  • faisant grandir et progresser
#  • faites progresser
#  • Faire progresser
#  • faire progressez
#  • fait toujours progresser
#  • fera progresser
#  • fait progresser
#  • font progresser
#  • faisant progresser
#  • faire pour faire progresser
#  • ferons progresser
#  • ferez progresser
#
# === total_autonomie (5 variants) ===
#  • totale autonomie
#  • total autonomie
#  • totale ou partiel autonomie
#  • Totale autonomie
#  • totale de fenêtre en toute autonomie
#
# === week_end (3 variants) ===
#  • week end
#  • Week end
#  • week ends
#
# === cdd_cdi (28 variants) ===
#  • CDD suivi CDI
#  • CDD ou un CDI
#  • CDD peut évoluer vers un CDI
#  • CDD renouvelable un CDI
#  • CDD Evolutif vers un CDI
#  • CDD reconductible en CDI
#  • CDD et du CDI
#  • cdd cdi
#  • CDD pour conclure sur un CDI
#  • CDD renouvelable avec possibilité de CDI
#  • CDD évolutif sur un CDI
#  • CDD voir CDI
#  • CDD avec possibilité de CDI
#  • CDD jusque fin août puis CDI
#  • CDD et le CDI
#  • CDD pouvant déboucher sur un CDI
#  • CDD évolutif en CDI
#  • CDD et pourquoi pas en CDI
#  • CDD peut déboucher sur un CDI
#  • CDD évolutif vers un CDI
#  • CDD et en CDI
#  • CDD pouvant aboutir sur un CDI
#  • cdd ou cdi
#  • CDD pouvant évoluer vers un CDI
#  • CDD voire un CDI
#  • CDD ou en CDI
#  • cdd et cdi
#  • CDD et une en CDI
#
# === autonomie_rigueur (21 variants) ===
#  • autonomie et de rigueur
#  • autonomie Ta rigueur
#  • autonomie et rigueur
#  • autonomie et de la rigueur
#  • Autonomie de rigueur
#  • Autonomie et Rigueur
#  • Autonomie Organisation Rigueur
#  • Autonomie et de rigueur
#  • autonomie ainsi que pour votre rigueur
#  • autonomie ainsi que la rigueur
#  • autonomie et la rigueur
#  • Autonomie Rigueur
#  • Autonomie Ponctualité Rigueur
#  • autonomie ainsi que votre rigueur
#  • autonomie et votre rigueur
#  • autonomie et de beaucoup de rigueur
#  • autonomie Faire preuve de rigueur
#  • autonomie rigueur
#  • autonomie et avec rigueur
#  • AUTONOMIE RIGUEUR
#  • Autonomie et rigueur
#
# === mois_prime (19 variants) ===
#  • mois et diverses Primes
#  • mois et prime
#  • mois plus primes
#  • mois et le cas échéant prime
#  • mois primes
#  • mois avec prime
#  • mois et des primes
#  • mois déplacement prime
#  • mois avec une prime
#  • mois hors primes
#  • mois Une prime
#  • mois de primes
#  • mois prime
#  • mois et une prime
#  • mois accompagnée de prime
#  • mois versé mensuellement prime
#  • mois de prime
#  • mois accompagnée de primes
#  • mois et primes
#
# === devenir_expert (20 variants) ===
#  • devenir un véritable expert
#  • devenu expert
#  • devenez un expert
#  • devenir de véritables experts
#  • Devenir un expert
#  • devenir expert
#  • Devenez expert
#  • Devenir un professionnel expert
#  • devenir Expert
#  • devenez expert
#  • deviendrez un Expert
#  • devenu un expert
#  • Devenez un véritable expert
#  • devenir nos managers ou nos experts
#  • devenir un expert
#  • devenir référent et expert
#  • Devenir le futur expert
#  • deviendrez un expert
#  • deviennent des professionnels experts
#  • deveniez expert
#
# === amelioration_continuer (1 variants) ===
#  • amelioration continue
#
# === remuneration_attractif (7 variants) ===
#  • remuneration attractif
#  • remuneration attractive
#  • REMUNERATION ATTRACTIVE
#  • Remuneration extremement attractive
#  • Remuneration attractive
#  • remuneration individuelle et collective attractive
#  • Remuneration tres attractive
#
# === remuneration_selon (7 variants) ===
#  • REMUNERATION Salaire fixe selon
#  • REMUNERATION INTERESSANTE SELON
#  • remuneration selon
#  • REMUNERATION Selon
#  • Remuneration selon
#  • REMUNERATION SELON
#  • REMUNERATION NEGOCIABLE SELON
#
# === prise_decision (1 variants) ===
#  • prise de decision
#
# === salair_fixe (2 variants) ===
#  • salaire motivant avec fixe
#  • salaire fixe
#
# === evolution_carriere (1 variants) ===
#  • evolution de carriere
#
# === declaration_social (4 variants) ===
#  • declarations de charges sociales
#  • declaration des charges sociales
#  • DECLARATION ANNUELLE SALAIRES DECLARATION SOCIALES
#  • DECLARATION SOCIALES
#
# === conge_paye (1 variants) ===
#  • conges payes
#
# === deplacement_ponctuel (1 variants) ===
#  • deplacements ponctuels
#
# === innovation_passion (3 variants) ===
#  • Innovation Passion
#  • innovation et passion
#  • innovation automobile et la passion
#
# === opportunite_carriere (1 variants) ===
#  • opportunites de carriere
#
# === mission_variee (1 variants) ===
#  • MISSIONS RICHES ET VARIEES
#
# === frais_deplacement (1 variants) ===
#  • FRAIS DE DEPLACEMENT
#
# === montee_competence (1 variants) ===
#  • montee en competences
#
# === cheque_vacance (1 variants) ===
#  • cheque vacance
#
# === collaborateur_passionne (1 variants) ===
#  • collaborateurs passionnes

# %%
# ------------------------------------------------------------------------------
# STEP 7.1: EXTEND STOP-WORDS & EXTRACT LEMMA VARIANTS
# ------------------------------------------------------------------------------

# 7.1.1 Download NLTK French stop-words and build base set
nltk.download('stopwords')
french_stopwords = set(stopwords.words('french'))

# 7.1.2 Define extra “in-between” tokens to filter out
additional_stopwords = [
    'alors', 'assez', 'avoir', 'bien', 'cahier', 'connaissance',
    'directement', 'essentiellement', 'ensuite', 'egalemer',
    'egalement', 'integralement', 'notamment', 'parfaitement',
    'particulieremer', 'plus', 'principalement', 'prioritairement',
    'progressivement', 'progressivemer', 'rapidement',
    'aussi', 'ainsi', 'donc', 'constant', 'continues', 'prevue',
    'prevues', 'possibles', 'possible', 'sont', 'individualisee',
    'soutien', 'personnalise', 'continue', 'veritable', 'tres',
    'tre', 'veritabl', 'extremement', 'futur'
]

# 7.1.3 Merge base and additional stop-words
french_stopwords |= set(additional_stopwords)

# 7.1.4 Load spaCy French model (disable parser, NER, textcat for speed)
nlp_stop = spacy.load("fr_core_news_sm", disable=["parser", "ner", "textcat"])

# ------------------------------------------------------------------------------
# STEP 7.2: PREPROCESSING FUNCTION
# ------------------------------------------------------------------------------
def preprocess_text(text: str) -> str:
    """
    Lowercase, strip accents, tokenize & lemmatize, remove stop-words.
    Returns a space-joined string of lemmas.
    """
    # Lowercase and remove accents
    txt = unidecode(text).lower()

    # Lemmatize and filter out stop-words
    doc = nlp_stop(txt)
    lemmas = [
        tok.lemma_.lower()
        for tok in doc
        if tok.is_alpha and tok.lemma_.lower() not in french_stopwords
    ]
    return " ".join(lemmas)

# ------------------------------------------------------------------------------
# STEP 7.3: BUILD LEMMA VARIANT MAPPING
# ------------------------------------------------------------------------------
lemma_variants = defaultdict(set)

for kw, forms in variants.items():
    for form in forms:
        lemma_form = preprocess_text(form)
        if lemma_form:  # skip empty results
            lemma_variants[kw].add(lemma_form)

# Convert each set of lemma-forms to a list
lemma_variants = {kw: list(s) for kw, s in lemma_variants.items()}

# ------------------------------------------------------------------------------
# STEP 7.4: INSPECT UNIQUE LEMMA FORMS
# ------------------------------------------------------------------------------
for kw, lemmas in lemma_variants.items():
    print(f"\n=== {kw} ({len(lemmas)} unique lemma forms) ===")
    for lm in lemmas:
        print(" •", lm)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alfonso/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# === ticket_restaurant (5 unique lemma forms) ===
#  • ticket resto
#  • ticket restau
#  • ticket restaurant restaurant
#  • ticket restaurant
#  • ticket restaurer
#
# === prendre_charge (10 unique lemma forms) ===
#  • prendra charge
#  • prendra preferentiellement charge
#  • prise charge
#  • prendre charge
#  • prendrez charge
#  • prendra techniquement charge
#  • prit charge
#  • prenon charge
#  • prendre fois charge
#  • prendre temporairement charge
#
# === grand_compte (9 unique lemma forms) ===
#  • grand compte compte
#  • grand compte
#  • grand livre justification compte
#  • grand deplacement compte
#  • grand compte grand compte
#  • grand volume grand compte
#  • grand moyen compte
#  • grand ampleur compte
#  • grand livre balance compte
#
# === sans_responsable (3 unique lemma forms) ===
#  • sans accident responsable
#  • sans responsable
#  • sans equivalence rattach responsable
#
# === taux_horaire (4 unique lemma forms) ===
#  • taux normal taux horaire
#  • taux brut horaire
#  • taux horaire complete taux horaire
#  • taux horaire
#
# === temps_partiel (11 unique lemma forms) ===
#  • temps plein partiel
#  • temps partiel temps partiel
#  • temps plein être temps partiel
#  • temps complet partiel
#  • temps complet temps partiel
#  • temps temps partiel
#  • temps partiel
#  • temps travail temps partiel
#  • temps travail partiel
#  • temps plein temps partiel
#  • temps pleinou temps partiel
#
# === ambiance_travail (8 unique lemma forms) ===
#  • ambiance condition travail
#  • ambiance reconnaissance travail
#  • ambiance travail
#  • ambiance agreabl travail
#  • ambiance favorable travail
#  • ambiance stimulant travail
#  • ambiance allier travail
#  • ambiance cadre travail
#
# === temps_plein (10 unique lemma forms) ===
#  • temps partiel temps plein
#  • temps pleinen plein
#  • temps choisir temps plein
#  • temps plein dentiste temps plein
#  • temps travail temps plein
#  • temps plein
#  • temps complet occuper temps plein
#  • temps partiel pouvoir evoluer plein
#  • temps partiel evolutif temps plein
#  • temps partiel plein
#
# === convention_collectif (1 unique lemma forms) ===
#  • convention collectif
#
# === fort_croissance (11 unique lemma forms) ===
#  • fort potentiel croissance
#  • fort croissance
#  • fort dynamique croissance
#  • fort strategie croissance
#  • fort perspectif croissance
#  • fort developpement croissance
#  • fort hyper croissance
#  • fort ambition croissance
#  • fort conner croissance
#  • fort politique croissance
#  • fort niveau croissance
#
# === chef_projet (15 unique lemma forms) ===
#  • chef directeur projet
#  • chef projet participer projet
#  • chef projet piloter projet
#  • chef projet projet
#  • chef projet confirmer projet
#  • chef responsable projet
#  • chef charge projet
#  • chef projet anime projet
#  • chef chantier grand projet
#  • chef cheffe projet
#  • chef chantier projet
#  • chef or or projet
#  • chef groupe installation electrique projet
#  • chef projet phase projet
#  • chef projet
#
# === minimum_garanti (4 unique lemma forms) ===
#  • minimum garanti
#  • minimum indicatif être garanti
#  • minimum mensuel garanti
#  • minimum remunere garanti
#
# === force_proposition (4 unique lemma forms) ===
#  • force proposition
#  • force conseil proposition
#  • force e proposition
#  • force conviction proposition
#
# === brut_annuel (5 unique lemma forms) ===
#  • brut fixe annuel
#  • brut mensuel variable annuel
#  • brut annuel
#  • brut mensuel salaire annuel
#  • brute annuel
#
# === haut_niveau (3 unique lemma forms) ===
#  • haut niveau
#  • haut gamme mode niveau
#  • haut niveau niveau
#
# === contrat_cdi (20 unique lemma forms) ===
#  • contrat salarie cdi
#  • contrat proposer être cdi
#  • contrat pouvoir evoluer vers cdi
#  • contrat être evolutif vers cdi
#  • contrat vue cdi
#  • contrat cdi
#  • contrat pouvoir evoluer cdi
#  • contrat pouvoir deboucher cdi
#  • contrat plein temps cdi
#  • contrat duree indeterminee cdi
#  • contrat être cdi
#  • contrat vouloir selectionner valeur cdi
#  • contrat cp cdi
#  • contrat pouvoir etre transforme cdi
#  • contrat evolutif cdi
#  • contrat interim pouvoir cdd cdi
#  • contrat interim possibilite cdi
#  • contrat long cdi
#  • contrat proposer cdi
#  • contrat travail cdi
#
# === euro_brut (8 unique lemma forms) ===
#  • euro annuel brut
#  • euro brut
#  • eur mensuel brut
#  • eur prime polyvalence brut
#  • eur brut
#  • eur annuel brut
#  • eur prime soiree brut
#  • eur fixe annuel brut
#
# === salaire_brut (15 unique lemma forms) ===
#  • salaire taux horaire brut
#  • salaire horaire brut
#  • salaire base brut
#  • salaire mensuel brut
#  • salaire base mensuel brut
#  • salaire attractif brut
#  • salaire province mensuel brut
#  • salaire minimum garanti brut
#  • salaire fixe brut
#  • salaire brut
#  • salaire affich brut
#  • salaire annuel brut
#  • salaire divers taux horaire brut
#  • salaire mentionn être brut
#  • salaire indique être montant brut
#
# === temps_complet (9 unique lemma forms) ===
#  • temps complete
#  • temps hospitalisation complete
#  • temps partiel complet
#  • temps non complet
#  • temps travail temps complet
#  • temps partiel possibilite temp complet
#  • temps choisir complet
#  • temps partiel temps complet
#  • temps complet
#
# === maison_individuel (1 unique lemma forms) ===
#  • maison individuel
#
# === brut_mensuel (3 unique lemma forms) ===
#  • brut prime mensuel
#  • brut mensuel
#  • brute mensuel
#
# === etre_force_proposition (9 unique lemma forms) ===
#  • etre responsable proposition
#  • etre creatif force proposition
#  • etre source proposition
#  • etre moteur force proposition
#  • etre acteur force proposition
#  • etre force proposition
#  • etre proposition
#  • etre volontaire force proposition
#  • etre reactif force proposition
#
# === formation_tout_long (13 unique lemma forms) ===
#  • formation taire long
#  • formation tout long
#  • formation être possibler tout long
#  • formation continuer tout long
#  • formation faire tout long
#  • formation assuree via integration long
#  • formation professionnel continuer tout long
#  • formation qualite tout long
#  • formation personnalis tout long
#  • formation accompagner tout long
#  • formation être prevuer tout long
#  • formation continu tout long
#  • formation long
#
# === prendre_initiative (9 unique lemma forms) ===
#  • prendre decision initiative
#  • prendre prendre initiative
#  • prendre part initiative
#  • prendre tout initiative
#  • prendre regulierement initiative
#  • prendre sans delai initiative
#  • prendre initiative
#  • prendre tout decision initiative
#  • prendre part activemer initiative
#
# === salair_selon (8 unique lemma forms) ===
#  • salaire être negocier selon
#  • salaire varie selon
#  • salaire selon
#  • salaire base selon
#  • salaire negociabl selon
#  • salaire être determiner selon
#  • salaire definir selon
#  • salaire negocier selon
#
# === prime_collectif (9 unique lemma forms) ===
#  • prime commercial collectif
#  • prime selon convention collectif
#  • prime indemnite selon convention collectif
#  • prime individuel prime collectif
#  • prime collectif
#  • prime productivite collectif
#  • prime individuel collectif
#  • prime panier selon convention collectif
#  • prime objectif individuel collectif
#
# === annuel_brut (2 unique lemma forms) ===
#  • annuel brut
#  • annuel brute
#
# === voir_confier (5 unique lemma forms) ===
#  • voir confier
#  • voir confiee
#  • verrez confier
#  • voyant confier
#  • verrez confier confier
#
# === faire_progresser (7 unique lemma forms) ===
#  • fait progresser
#  • feron progresser
#  • faire progresser
#  • faire grandir progresser
#  • faire toujours progresser
#  • faire carriere progresser
#  • faire faire progresser
#
# === total_autonomie (3 unique lemma forms) ===
#  • total autonomie
#  • total partiel autonomie
#  • total fenetre tout autonomie
#
# === week_end (1 unique lemma forms) ===
#  • week end
#
# === cdd_cdi (16 unique lemma forms) ===
#  • cdd renouvelable cdi
#  • cdd pourquoi cdi
#  • cdd evolutif cdi
#  • cdd pouvoir aboutir cdi
#  • cdd possibilite cdi
#  • cdd jusqu fin aout pouvoir cdi
#  • cdd voir cdi
#  • cdd pouvoir deboucher cdi
#  • cdd pouvoir evoluer vers cdi
#  • cdd conclure cdi
#  • cdd reconductible cdi
#  • cdd renouvelable possibilite cdi
#  • cdd suivre cdi
#  • cdd evolutif vers cdi
#  • cdd cdi
#  • cdd voire cdi
#
# === autonomie_rigueur (5 unique lemma forms) ===
#  • autonomie faire preuve rigueur
#  • autonomie ponctualit rigueur
#  • autonomie rigueur
#  • autonomie organisation rigueur
#  • autonomie beaucoup rigueur
#
# === mois_prime (7 unique lemma forms) ===
#  • mois deplacement prime
#  • mois vers mensuellement prime
#  • mois accompagnee prime
#  • mois prime
#  • mois cas echeer prime
#  • mois hors prime
#  • mois divers prime
#
# === devenir_expert (5 unique lemma forms) ===
#  • devenir expert
#  • devenir futur expert
#  • devenir referent expert
#  • devenir manager expert
#  • devenir professionnel expert
#
# === amelioration_continuer (1 unique lemma forms) ===
#  • amelioration continuer
#
# === remuneration_attractif (2 unique lemma forms) ===
#  • remuneration attractif
#  • remuneration individuel collectif attractif
#
# === remuneration_selon (4 unique lemma forms) ===
#  • remuneration interessant selon
#  • remuneration salair fixe selon
#  • remuneration selon
#  • remuneration negociabl selon
#
# === prise_decision (1 unique lemma forms) ===
#  • prise decision
#
# === salair_fixe (2 unique lemma forms) ===
#  • salaire motiver fixe
#  • salaire fixe
#
# === evolution_carriere (1 unique lemma forms) ===
#  • evolution carriere
#
# === declaration_social (3 unique lemma forms) ===
#  • declaration social
#  • declaration annuel salaire declaration social
#  • declaration charge social
#
# === conge_paye (1 unique lemma forms) ===
#  • conge paye
#
# === deplacement_ponctuel (1 unique lemma forms) ===
#  • deplacement ponctuel
#
# === innovation_passion (2 unique lemma forms) ===
#  • innovation automobile passion
#  • innovation passion
#
# === opportunite_carriere (1 unique lemma forms) ===
#  • opportunite carriere
#
# === mission_variee (1 unique lemma forms) ===
#  • mission riche variees
#
# === frais_deplacement (1 unique lemma forms) ===
#  • frais deplacement
#
# === montee_competence (1 unique lemma forms) ===
#  • montee competence
#
# === cheque_vacance (1 unique lemma forms) ===
#  • cheque vacance
#
# === collaborateur_passionne (1 unique lemma forms) ===
#  • collaborateur passionne

# %%
# ------------------------------------------------------------------------------
# STEP 8: UPDATE ATTRIBUTE BASE WITH NEW EXPRESSIONS
# ------------------------------------------------------------------------------

# 8.1 Load your existing attribute table
# ————————————————————————————
attribute_base = pd.read_excel(file)

# 8.2 Define new attributes and their expressions
# ————————————————————————————
new_entries = {
    "Tickets restaurants": [
        "ticket restau",
        "ticket resto",
    ],
    "Chèques vacance": [
        "cheque vacance",
    ],
    "Responsabilités dans le poste": [
        "prendra en charge",
        "prendre en charge",
        "prendrez en charge",
        "grand compte",
        "voir confier",
        "verrez confier",
        "prise de decision",
    ],
    "Autonomie dans l’exécution des tâches": [
        "sans responsable",
        "force proposition",
        "autonomie",
    ],
    "Niveau de rémunération": [
        "taux horaire",
        "taux brut horaire",
        "euro",
        "€",
    ],
    "Environnement social": [
        "reconnaissance travail",
        "ambiance travail",
        "ambiance agreabl",
        "ambiance favorable",
        "ambiance stimulant",
        "collaborateurs passionnes",
    ],
    "Bonnes perspectives de carrière": [
        "fort potentiel de croissance",
        "fortes perspectives de croissance",
        "forte politique de croissance",
        "evolution de carriere",
        "opportunites de carriere",
    ],
    "Responsabilité de leadership incluse": [
        "chef de projet",
    ],
    "Toute autre mention de salaire": [
        "minimum rémunéré garanti",
        "minimum indicatif est garanti",
        "minimum mensuel garanti",
    ],
    "Contrat à temps plein": [
        "temps complet",
    ],
    "Choix entre temps plein et temps partiel": [
        "temps partiel complet",
        "temps partiel possibilite temp complet",
        "temps partiel temps complet",
        "temps partiel temps plein",
        "temps partiel plein",
    ],
    "Formation en cours d’emploi": [
        "formation professionnelle continue",
        "formation tout au long",
        "Formation assurée",
        "formations au long",
        "devenir expert",
        "amelioration continuer",
        "montee en competences",
    ],
    "Salaire compétitif": [
        "remuneration attractive",
        "remuneration individuelle et collective attractive",
        "remuneration interessant",
    ],
    "Variété des tâches": [
        "mission riche variees",
    ],
}

# 8.3 Manually specify aggregates for new attributes category
# ————————————————————————————
aggregate_mapping = {
    "Tickets restaurants": "Avantages mineurs",
    "Chèques vacance":   "Avantages mineurs",
}

# 8.4 Fill in aggregate mapping for existing attributes
# ————————————————————————————
for attr in new_entries:
    if attr not in aggregate_mapping:
        existing = attribute_base.loc[
            attribute_base["attribute_category_fr"] == attr,
            "aggregate_category_fr"
        ].unique()
        if len(existing) == 0:
            raise ValueError(f"No aggregate_category_fr found for attribute “{attr}”")
        aggregate_mapping[attr] = existing[0]

# 8.5 Build list of new rows (if not already present)
# ————————————————————————————
rows_to_add = []
for attr, expr_list in new_entries.items():
    agg = aggregate_mapping[attr]
    for expr in expr_list:
        mask = (
            (attribute_base["attribute_category_fr"] == attr) &
            (attribute_base["expression"] == expr)
        )
        if not mask.any():
            rows_to_add.append({
                "aggregate_category_fr": agg,
                "attribute_category_fr": attr,
                "expression":            expr,
            })

# 8.6 Append new rows and save updated table
# ————————————————————————————
# Append
attribute_base = pd.concat(
    [attribute_base, pd.DataFrame(rows_to_add)],
    ignore_index=True
)
attribute_base.sort_values("attribute_category_fr", inplace=True)

# Save
output_file = Path(project_root) / "data" / "attribute_base_processedV2.xlsx"
attribute_base.to_excel(output_file, index=False)

# Report
print(f"Added {len(rows_to_add)} new rows and wrote out updated Excel.")```
# Out:
# Added 46 new rows and wrote out updated CSV.
