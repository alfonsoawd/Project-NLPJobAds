# %%
import os
import re
import unicodedata
import random
import csv
from pathlib import Path

import pandas as pd
import numpy as np

import spacy
from gensim.models import FastText
from gensim.models.phrases import Phrases, Phraser

import nltk
from unidecode import unidecode


# ----------------------------------------
# 1. Load French NLP Pipeline
# ----------------------------------------
nlp = spacy.load("fr_core_news_sm", disable=["parser","ner"])
french_sw = nlp.Defaults.stop_words

# ----------------------------------------
# 1. Paths & Parameters
# ----------------------------------------
project_root = Path().resolve().parent
attribute_file = project_root / "data" / "attribute_base_processedV2.xlsx"
jocas_dir = "/Users/alfonso/Desktop/JOCAS"  # adjust if needed
sample_size     = 50
random_seed     = 42

# FastText & phrase-detector hyperparams
vector_size      = 100
window_size      = 5
min_count        = 5
workers          = 4
phrase_min_count = 10
phrase_threshold = 10

# French stop-words (for PREPROCESSING ONLY)
french_stopwords = set(stopwords.words("french"))

# ----------------------------------------
# 2. — Define preprocessing function
# ----------------------------------------
def preprocess_text(text: str) -> str:
    """
    Lowercase, strip accents, tokenize & lemmatize, remove stop-words.
    Returns a space-joined string of lemmas.
    """
    # Lowercase and remove accents
    txt = unidecode(text).lower()
    # Lemmatize & filter
    doc = nlp_stop(txt)
    lemmas = [
        tok.lemma_.lower()
        for tok in doc
        if tok.is_alpha
           and tok.lemma_.lower() not in french_stopwords
           and len(tok.lemma_) > 1
    ]
    return " ".join(lemmas)

# ----------------------------------------
# 3. — Load & prepare attribute base
# ----------------------------------------
attribute_df = (
    pd.read_excel(attribute_file)
      .loc[:, ["attribute_category_fr", "expression"]]
      .dropna()
)

# Build lemma-sets per category for later filtering
cat_to_lemmas = {}
for cat, grp in attribute_df.groupby("attribute_category_fr"):
    lemmas = set()
    for expr in grp["expression"].astype(str):
        for tok in nlp(expr):
            if tok.is_alpha and len(tok.lemma_) > 1:
                lemmas.add(tok.lemma_.lower())
    cat_to_lemmas[cat] = lemmas

# %%
cat_to_lemmas
# Out:
# {'Autonomie dans l’exécution des tâches': {'action',
#   'autogestion',
#   'autonome',
#   'autonomie',
#   'capacité',
#   'dans',
#   'direct',
#   'force',
#   'gestion',
#   'indépendance',
#   'initiative',
#   'le',
#   'liberter',
#   'mission',
#   'organisation',
#   'personnel',
#   'poste',
#   'prise',
#   'professionnel',
#   'proposition',
#   'responsable',
#   'sans',
#   'supervision',
#   'travail'},
#  'Bel emplacement': {'agréable',
#   'attractif',
#   'bord',
#   'cadre',
#   'centre',
#   'commodité',
#   'de',
#   'dynamique',
#   'emplacement',
#   'environnement',
#   'exceptionnel',
#   'géographique',
#   'idéal',
#   'imprenable',
#   'le',
#   'localisation',
#   'mer',
#   'nature',
#   'pittoresque',
#   'priser',
#   'privilégier',
#   'proche',
#   'proximité',
#   'quartier',
#   'rechercher',
#   'secteur',
#   'site',
#   'situation',
#   'verdoyer',
#   'ville',
#   'vue',
#   'zone'},
#  'Bonne rémunération des heures supplémentaires': {'compensation',
#   'de',
#   'en',
#   'heure',
#   'majoration',
#   'majorer',
#   'paiement',
#   'payer',
#   'plus',
#   'pour',
#   'rémunération',
#   'rémunérer',
#   'sup',
#   'supp',
#   'supplémentaire'},
#  'Bonnes perspectives de carrière': {'accès',
#   'avancement',
#   'carriere',
#   'carrière',
#   'cheminement',
#   'croissance',
#   'de',
#   'développement',
#   'evolution',
#   'faire',
#   'fort',
#   'futur',
#   'interne',
#   'mobilité',
#   'opportunite',
#   'opportunité',
#   'parcours',
#   'perspectif',
#   'perspective',
#   'plan',
#   'politique',
#   'possibiliter',
#   'possibilité',
#   'poste',
#   'potentiel',
#   'professionnel',
#   'projet',
#   'promotion',
#   'responsabilité',
#   'un',
#   'évolutif',
#   'évolution'},
#  'Bons collègues': {'accueillant',
#   'agréable',
#   'ambiance',
#   'avec',
#   'bienveillant',
#   'bon',
#   'climat',
#   'cohésion',
#   'collaborateur',
#   'collaboratif',
#   'collaboration',
#   'collègue',
#   'compétent',
#   'de',
#   'dynamique',
#   'engager',
#   'entente',
#   'entraider',
#   'entrer',
#   'esprit',
#   'expérimenté',
#   'humain',
#   'motiver',
#   'pair',
#   'passionné',
#   'professionnel',
#   'qualité',
#   'relation',
#   'solidaire',
#   'souder',
#   'sympathique',
#   'taille',
#   'travailler',
#   'un',
#   'écoute',
#   'équipe'},
#  'Chalet d’entreprise': {'appartement',
#   'bungalow',
#   'cabane',
#   'chalet',
#   'corporatif',
#   'de',
#   'détente',
#   'entreprise',
#   'fonction',
#   'gîte',
#   'hébergemer',
#   'logement',
#   'loisir',
#   'maison',
#   'partager',
#   'pavillon',
#   'refuge',
#   'résidence',
#   'saisonnier',
#   'secondaire',
#   'société',
#   'vacance',
#   'viller'},
#  'Choix entre temps plein et temps partiel': {'ajustable',
#   'au',
#   'choix',
#   'complet',
#   'contrat',
#   'de',
#   'en',
#   'ou',
#   'partiel',
#   'plein',
#   'possibilite',
#   'possibilité',
#   'poste',
#   'temp',
#   'temps',
#   'tp',
#   'travail',
#   'tt'},
#  'Chèques vacance': {'cheque', 'vacance'},
#  'Congés flexibles/étendus': {'absence',
#   'additionnel',
#   'aménagement',
#   'avantageux',
#   'congé',
#   'de',
#   'flexibilité',
#   'flexible',
#   'férié',
#   'jour',
#   'offrir',
#   'payer',
#   'personnel',
#   'politique',
#   'possibilité',
#   'prolonger',
#   'repos',
#   'rtt',
#   'sabbatique',
#   'sans',
#   'semaine',
#   'solde',
#   'supplémentaire',
#   'temps',
#   'travail',
#   'vacance'},
#  'Contrat à durée déterminée': {'besoin',
#   'cdd',
#   'contrat',
#   'de',
#   'durée',
#   'déterminer',
#   'emploi',
#   'engagement',
#   'intérimaire',
#   'limité',
#   'mission',
#   'occasionnel',
#   'poste',
#   'pour',
#   'remplacement',
#   'saisonnier',
#   'temporaire',
#   'terme',
#   'travail'},
#  'Contrat à temps partiel': {'partiel', 'temps', 'tp'},
#  'Contrat à temps plein': {'complet', 'plein', 'temps'},
#  'Emplacement central': {'accès',
#   'au',
#   'central',
#   'centre',
#   'commerce',
#   'cœur',
#   'de',
#   'emplacement',
#   'facile',
#   'gar',
#   'hyper',
#   'localisation',
#   'métro',
#   'plein',
#   'proche',
#   'proximité',
#   'quartier',
#   'stratégique',
#   'transport',
#   'urbain',
#   'ville',
#   'zone'},
#  'Emploi permanent': {'cdi',
#   'contrat',
#   'de',
#   'durée',
#   'emploi',
#   'engagement',
#   'fixe',
#   'indéterminé',
#   'long',
#   'permanent',
#   'poste',
#   'précis',
#   'pérenne',
#   'sans',
#   'stable',
#   'terme',
#   'travail'},
#  'Emploi sur appel': {'appel',
#   'astreinte',
#   'au',
#   'besoin',
#   'contrat',
#   'demande',
#   'disponibilité',
#   'emploi',
#   'en',
#   'immédiat',
#   'intervention',
#   'job',
#   'le',
#   'lever',
#   'mission',
#   'occasionnel',
#   'pied',
#   'ponctuel',
#   'poste',
#   'remplacemer',
#   'renfort',
#   'requérir',
#   'sur',
#   'temporaire',
#   'travail',
#   'tâche',
#   'urgent',
#   'vacataire',
#   'vacation'},
#  'Emploi temporaire': {'contrat',
#   'court',
#   'de',
#   'durée',
#   'emploi',
#   'en',
#   'intérim',
#   'intérimaire',
#   'limité',
#   'mission',
#   'ponctuel',
#   'poste',
#   'remplacement',
#   'saisonnier',
#   'temporaire',
#   'travail',
#   'vacation'},
#  'Environnement social': {'agreabl',
#   'agréable',
#   'ambiance',
#   'au',
#   'bienveillant',
#   'bon',
#   'cadre',
#   'chaleureux',
#   'climat',
#   'collaborateur',
#   'convivial',
#   'culture',
#   'de',
#   'dynamique',
#   'détendre',
#   'entreprise',
#   'environnement',
#   'espace',
#   'esprit',
#   'familial',
#   'favorable',
#   'humain',
#   'interne',
#   'milieu',
#   'motiver',
#   'passionne',
#   'positif',
#   'professionnel',
#   'qualité',
#   'reconnaissance',
#   'relation',
#   'respectueux',
#   'serein',
#   'social',
#   'stimulant',
#   'travail',
#   'valorisant',
#   'vie',
#   'équipe'},
#  'Espace de bureau partagé': {'bureau',
#   'collectif',
#   'commun',
#   'convivial',
#   'coworking',
#   'de',
#   'en',
#   'environnement',
#   'espace',
#   'open',
#   'ouvert',
#   'ouvrir',
#   'partager',
#   'plateau',
#   'poste',
#   'space',
#   'travail'},
#  'Exemption des réglementations sur le temps de travail': {'autonomie',
#   'cadre',
#   'chef',
#   'collectif',
#   'contrat',
#   'dans',
#   'de',
#   'directeur',
#   'direction',
#   'dirigeant',
#   'département',
#   'exonération',
#   'fonction',
#   'forfaire',
#   'forfaitaire',
#   'horaire',
#   'indépender',
#   'jour',
#   'le',
#   'management',
#   'manager',
#   'non',
#   'organisation',
#   'poste',
#   'responsabiliter',
#   'responsable',
#   'règle',
#   'régime',
#   'service',
#   'soumettre',
#   'statut',
#   'sur',
#   'temps',
#   'travail',
#   'équipe'},
#  'Formation en cours d’emploi': {'accompagnement',
#   'accès',
#   'alternance',
#   'amelioration',
#   'apprentissage',
#   'assurer',
#   'atelier',
#   'au',
#   'bilan',
#   'certifiant',
#   'coaching',
#   'competence',
#   'compétence',
#   'continuer',
#   'de',
#   'devenir',
#   'diplômant',
#   'droit',
#   'développement',
#   'en',
#   'entreprise',
#   'expert',
#   'financer',
#   'formation',
#   'interne',
#   'le',
#   'ligne',
#   'long',
#   'mentorat',
#   'montee',
#   'monter',
#   'mooc',
#   'offrir',
#   'parcours',
#   'perfectionnement',
#   'permanent',
#   'plan',
#   'poste',
#   'professionnel',
#   'programme',
#   'qualifiant',
#   'renforcement',
#   'régulier',
#   'session',
#   'stage',
#   'sur',
#   'séminair',
#   'tas',
#   'tout',
#   'tutorat',
#   'un',
#   'vie',
#   'éducation',
#   'évolution'},
#  'Heures supplémentaires requises': {'accroître',
#   'assurer',
#   'besoin',
#   'complémentaire',
#   'contrat',
#   'de',
#   'dehors',
#   'demander',
#   'disponibilité',
#   'dépassement',
#   'en',
#   'flexibilité',
#   'heure',
#   'horaire',
#   'légal',
#   'obligation',
#   'obligatoire',
#   'plus',
#   'possibiliter',
#   'possible',
#   'prolonger',
#   'prévoir',
#   'requérir',
#   'régulier',
#   'supp',
#   'supplémentaire',
#   'temps',
#   'travail',
#   'un',
#   'étendu'},
#  'Horaire de travail de jour régulier': {'bureau',
#   'classique',
#   'conster',
#   'continu',
#   'de',
#   'emploi',
#   'en',
#   'fixe',
#   'habituel',
#   'heure',
#   'horaire',
#   'journée',
#   'normal',
#   'planning',
#   'régulier',
#   'stable',
#   'standard',
#   'temps',
#   'traditionnel',
#   'travail'},
#  'Niveau de rémunération': {'annuel',
#   'attractif',
#   'barémer',
#   'base',
#   'brut',
#   'de',
#   'euro',
#   'expérience',
#   'fixe',
#   'fourchette',
#   'grill',
#   'horaire',
#   'mensuel',
#   'net',
#   'niveau',
#   'profil',
#   'rémunération',
#   'salaire',
#   'salarial',
#   'selon',
#   'taux',
#   'échelle'},
#  'Place de parking sur site': {'air',
#   'couvert',
#   'de',
#   'disposition',
#   'dédier',
#   'emplacement',
#   'entreprise',
#   'facile',
#   'garage',
#   'gratuit',
#   'parking',
#   'place',
#   'priver',
#   'réserver',
#   'souterrain',
#   'stationnement',
#   'sécuriser'},
#  'Possibilité de télétravail': {'chez',
#   'de',
#   'depuis',
#   'distance',
#   'distanciel',
#   'en',
#   'environnement',
#   'et',
#   'flexibilité',
#   'flexible',
#   'home',
#   'hybride',
#   'jour',
#   'lieu',
#   'modalité',
#   'mode',
#   'office',
#   'organisation',
#   'partiel',
#   'politique',
#   'ponctuel',
#   'possibilité',
#   'possible',
#   'présentiel',
#   'remote',
#   'régulier',
#   'soi',
#   'travail',
#   'télétravail'},
#  'Possibilité d’emprunt immobilier': {'accession',
#   'achat',
#   'aide',
#   'avantageux',
#   'condition',
#   'crédit',
#   'de',
#   'employeur',
#   'faciliter',
#   'favorable',
#   'financement',
#   'habitat',
#   'immobilier',
#   'le',
#   'logement',
#   'offrir',
#   'propriété',
#   'prêt',
#   'réduit',
#   'soutien',
#   'taux',
#   'zéro'},
#  'Possibilité d’horaires flexibles': {'adaptable',
#   'ajustable',
#   'aménageable',
#   'aménagement',
#   'aménager',
#   'autonome',
#   'carte',
#   'de',
#   'décaler',
#   'en',
#   'flexibilité',
#   'flexible',
#   'gestion',
#   'horaire',
#   'le',
#   'libre',
#   'modulable',
#   'modulation',
#   'personnaliser',
#   'plage',
#   'possibilité',
#   'souple',
#   'temps',
#   'travail',
#   'télétravail',
#   'variable'},
#  'Prime à l’embauche': {'arrivée',
#   'avantage',
#   'bienvenue',
#   'bonus',
#   'de',
#   'démarrage',
#   'embauch',
#   'entrée',
#   'exceptionnelle',
#   'intégration',
#   'prime',
#   'recrutement'},
#  'Programme d’inclusion travail-vie personnelle': {'adapter',
#   'aménageable',
#   'aménagement',
#   'attention',
#   'au',
#   'besoin',
#   'cadre',
#   'compatible',
#   'compte',
#   'conciliation',
#   'condition',
#   'de',
#   'démarche',
#   'en',
#   'engagement',
#   'environnement',
#   'et',
#   'familial',
#   'favorable',
#   'flexibilité',
#   'flexible',
#   'horaire',
#   'inclusion',
#   'le',
#   'organisation',
#   'organisationnel',
#   'perso',
#   'personnel',
#   'politique',
#   'porter',
#   'prise',
#   'priver',
#   'pro',
#   'professionnel',
#   'qualité',
#   'qvt',
#   'respect',
#   'respectueux',
#   'rse',
#   'rythme',
#   'souplesse',
#   'temps',
#   'travail',
#   'vie',
#   'épanouissement',
#   'équilibre',
#   'équilibré'},
#  'Responsabilité de leadership incluse': {'chef',
#   'coordination',
#   'de',
#   'direction',
#   'encadrement',
#   'fonction',
#   'gestion',
#   'hiérarchique',
#   'humain',
#   'leadership',
#   'management',
#   'manager',
#   'managérial',
#   'opérationnel',
#   'personnel',
#   'poste',
#   'projet',
#   'responsabilité',
#   'responsable',
#   'ressource',
#   'rôle',
#   'service',
#   'stratégique',
#   'supervision',
#   'équipe'},
#  'Responsabilités dans le poste': {'autonomie',
#   'charge',
#   'compte',
#   'confiance',
#   'confier',
#   'de',
#   'decision',
#   'décision',
#   'décisionnel',
#   'en',
#   'fonction',
#   'gestion',
#   'global',
#   'grand',
#   'mission',
#   'pilotage',
#   'poste',
#   'prendra',
#   'prendre',
#   'prise',
#   'projet',
#   'responsabiliter',
#   'responsabilité',
#   'responsable',
#   'stratégique',
#   'verrez',
#   'voir',
#   'étendre'},
#  'Régime de retraite': {'bénéfice',
#   'caisse',
#   'capital',
#   'charge',
#   'collectif',
#   'complément',
#   'complémentaire',
#   'cotisation',
#   'de',
#   'dispositif',
#   'en',
#   'entreprise',
#   'obligatoire',
#   'plan',
#   'prise',
#   'rent',
#   'retraire',
#   'retraite',
#   'régime',
#   'supplémentaire',
#   'système',
#   'un',
#   'épargne'},
#  'Régime d’assurance': {'accident',
#   'adhésion',
#   'assurance',
#   'charge',
#   'collectif',
#   'complémentaire',
#   'de',
#   'décè',
#   'en',
#   'entreprise',
#   'forfaire',
#   'garantie',
#   'incapacité',
#   'invalidité',
#   'le',
#   'mutuel',
#   'mutuelle',
#   'prise',
#   'protection',
#   'prévention',
#   'prévoyanc',
#   'prévoyance',
#   'santé',
#   'social',
#   'travail',
#   'vie'},
#  'Salaire compétitif': {'attractif',
#   'au',
#   'avantageux',
#   'collectif',
#   'compétitif',
#   'concurrentiel',
#   'condition',
#   'et',
#   'individuel',
#   'interessant',
#   'intéressant',
#   'marché',
#   'motiver',
#   'négociable',
#   'package',
#   'remuneration',
#   'rémunération',
#   'salaire',
#   'salarial',
#   'stimulant',
#   'supérieur',
#   'valorisant',
#   'évolutif'},
#  'Salaire selon convention collective': {'accord',
#   'barèm',
#   'collectif',
#   'convention',
#   'conventionnel',
#   'conventionner',
#   'de',
#   'encadrer',
#   'fixer',
#   'grill',
#   'grille',
#   'le',
#   'par',
#   'rémunération',
#   'salaire',
#   'salarial',
#   'selon'},
#  'Salle de sport ou équipe sportive de l’entreprise': {'activité',
#   'centre',
#   'club',
#   'coach',
#   'cours',
#   'de',
#   'en',
#   'fitnes',
#   'football',
#   'forme',
#   'gym',
#   'installation',
#   'musculation',
#   'programme',
#   'remettre',
#   'salle',
#   'sport',
#   'sportif',
#   'séance',
#   'tournois',
#   'yoga',
#   'équipe',
#   'événement'},
#  'Service de santé au travail': {'accompagnement',
#   'assistance',
#   'bilan',
#   'consultation',
#   'de',
#   'et',
#   'infirmier',
#   'médecine',
#   'médical',
#   'place',
#   'programme',
#   'prévention',
#   'santé',
#   'service',
#   'site',
#   'soin',
#   'suivre',
#   'sur',
#   'sécurité',
#   'travail',
#   'vaccination'},
#  'Système de rémunération incitative': {'annuel',
#   'au',
#   'bonus',
#   'commission',
#   'commissionnement',
#   'de',
#   'exceptionnel',
#   'incitatif',
#   'le',
#   'lier',
#   'mérite',
#   'objectif',
#   'option',
#   'performance',
#   'plan',
#   'prime',
#   'rendement',
#   'rémunération',
#   'résultat',
#   'stock',
#   'sur',
#   'système',
#   'variable'},
#  'Tickets restaurants': {'restau', 'resto', 'ticket'},
#  'Tout programme de bien-être': {'activité',
#   'atelier',
#   'coaching',
#   'de',
#   'détente',
#   'environnement',
#   'espace',
#   'gestion',
#   'massage',
#   'mindfulness',
#   'paus',
#   'perso',
#   'personnel',
#   'politique',
#   'pro',
#   'programm',
#   'qualité',
#   'qvt',
#   'relaxante',
#   'sain',
#   'santé',
#   'stress',
#   'séance',
#   'vie',
#   'équilibre'},
#  'Toute autre mention de salaire': {'avantage',
#   'complément',
#   'compétence',
#   'de',
#   'divers',
#   'en',
#   'expérience',
#   'fixe',
#   'garanti',
#   'global',
#   'indicatif',
#   'mensuel',
#   'minimum',
#   'mois',
#   'nature',
#   'négocier',
#   'package',
#   'paie',
#   'prime',
#   'rémunération',
#   'rémunérer',
#   'salaire',
#   'salarial',
#   'selon',
#   'structure',
#   'variable',
#   'verser',
#   'élément',
#   'être'},
#  'Travail impliquant des déplacements': {'déplacement',
#   'exigé',
#   'fréquent',
#   'international',
#   'itinérant',
#   'mobilité',
#   'national',
#   'nomade',
#   'permettre',
#   'ponctuel',
#   'professionnel',
#   'présence',
#   'requérir',
#   'terrain',
#   'tourner',
#   'voyage'},
#  'Travail le week-end/soir/nuit': {'astreinte',
#   'atypique',
#   'avec',
#   'contraindre',
#   'de',
#   'dimanche',
#   'dominical',
#   'décaler',
#   'emploi',
#   'en',
#   'end',
#   'fin',
#   'fractionné',
#   'férié',
#   'horaire',
#   'jour',
#   'journée',
#   'le',
#   'nocturne',
#   'nuit',
#   'plage',
#   'poste',
#   'présence',
#   'requérir',
#   'rotation',
#   'samedi',
#   'soir',
#   'soirée',
#   'temps',
#   'travail',
#   'week',
#   'étendre',
#   'étendu'},
#  'Travail par postes': {'alternance',
#   'alterner',
#   'continu',
#   'cycle',
#   'cyclique',
#   'de',
#   'emploi',
#   'en',
#   'faction',
#   'fractionné',
#   'horaire',
#   'planning',
#   'poste',
#   'poster',
#   'quart',
#   'rotation',
#   'roulement',
#   'service',
#   'shift',
#   'tournant',
#   'tourner',
#   'travail',
#   'variable',
#   'équipe'},
#  'Tâches intéressantes': {'activité',
#   'captivant',
#   'contenu',
#   'de',
#   'enjeu',
#   'enrichissant',
#   'et',
#   'inspirer',
#   'intéressant',
#   'mission',
#   'motivant',
#   'motiver',
#   'métier',
#   'passionner',
#   'porteur',
#   'projet',
#   'riche',
#   'sens',
#   'stimulant',
#   'travail',
#   'utile',
#   'valorisant',
#   'varier',
#   'épanouissant'},
#  'Tâches stimulantes': {'ambitieux',
#   'challenge',
#   'challengeant',
#   'complexe',
#   'de',
#   'enjeu',
#   'enjeux',
#   'exigeant',
#   'exiger',
#   'fort',
#   'haut',
#   'haute',
#   'impact',
#   'important',
#   'intensif',
#   'mission',
#   'niveau',
#   'projet',
#   'responsabilité',
#   'situation',
#   'stimulant',
#   'stratégique'},
#  'Variété des tâches': {'activité',
#   'contenu',
#   'diversifier',
#   'diversité',
#   'emploi',
#   'environnement',
#   'fonction',
#   'mission',
#   'multifonction',
#   'multiple',
#   'polyvalence',
#   'polyvalent',
#   'poste',
#   'riche',
#   'transverse',
#   'tâche',
#   'variees',
#   'varier',
#   'évolutif'},
#  'Véhicule de fonction': {'attribuer',
#   'automobile',
#   'avantage',
#   'car',
#   'carburer',
#   'carte',
#   'de',
#   'en',
#   'flotte',
#   'leasing',
#   'location',
#   'mobilité',
#   'nature',
#   'professionnel',
#   'service',
#   'société',
#   'transport',
#   'utilitaire',
#   'voiture',
#   'véhicule'}}

# %%
# ----------------------------------------
# 3. Ingest & Aggregate JOCAS Job Ads
# ----------------------------------------

# Initialize container
jocas_list = []


# Walk though source folders
for source_folder in os.listdir(jocas_dir):
    source_path = os.path.join(jocas_dir, source_folder)
    
    if os.path.isdir(source_path):
        # Collect all csv files under this source
        csv_files = []
        for root, dirs, files in os.walk(source_path):
            for file in files:
                
                # Case-insensitive check for .csv files
                if file.lower().endswith('.csv'):
                    csv_files.append(os.path.join(root, file))
        
        print(f"Found {len(csv_files)} CSV files in source folder: {source_folder}")
        
        if not csv_files:
            continue
        
        # Select up to 50 csv files from this source
        if len(csv_files) > 50:
            selected_files = random.sample(csv_files, 50)
        else:
            selected_files = csv_files
        
        print(f"Processing {len(selected_files)} files from source folder: {source_folder}")
        
        # Process each selected CSV file
        for file_path in selected_files:
            try:
                df = pd.read_csv(
                    file_path,
                    header=0,
                    sep=';',
                    on_bad_lines='skip',
                    low_memory=False,
                    quoting=csv.QUOTE_MINIMAL,
                    escapechar='\\'
                )
                jocas_list.append(df)
            except Exception as e:
                print(f"Failed to read {file_path}: {e}")

        print(f"Finished processing source folder: {source_folder}")

# Aggregate all dataframes into one
df_job = pd.concat(jocas_list, ignore_index=True)
print(f"Total job ads: {len(df_job)}")
# Out:
# Found 361 CSV files in source folder: regionsjob_nord
# Processing 50 files from source folder: regionsjob_nord
# Finished processing source folder: regionsjob_nord
# Found 357 CSV files in source folder: regionsjob_paris
# Processing 50 files from source folder: regionsjob_paris
# Finished processing source folder: regionsjob_paris
# Found 359 CSV files in source folder: regionsjob_rhonealpes
# Processing 50 files from source folder: regionsjob_rhonealpes
# Finished processing source folder: regionsjob_rhonealpes
# Found 362 CSV files in source folder: apec
# Processing 50 files from source folder: apec
# Finished processing source folder: apec
# Found 169 CSV files in source folder: keljob
# Processing 50 files from source folder: keljob
# Finished processing source folder: keljob
# Found 360 CSV files in source folder: regionsjob_sudouest
# Processing 50 files from source folder: regionsjob_sudouest
# Finished processing source folder: regionsjob_sudouest
# Found 361 CSV files in source folder: regionsjob_paca
# Processing 50 files from source folder: regionsjob_paca
# Finished processing source folder: regionsjob_paca
# Found 152 CSV files in source folder: viadeo
# Processing 50 files from source folder: viadeo
# Finished processing source folder: viadeo
# Found 358 CSV files in source folder: regionsjob_ouest
# Processing 50 files from source folder: regionsjob_ouest
# Finished processing source folder: regionsjob_ouest
# Found 319 CSV files in source folder: jobintree
# Processing 50 files from source folder: jobintree
# Finished processing source folder: jobintree
# Found 356 CSV files in source folder: regionsjob_centre
# Processing 50 files from source folder: regionsjob_centre
# Finished processing source folder: regionsjob_centre
# Found 362 CSV files in source folder: cadreo
# Processing 50 files from source folder: cadreo
# Finished processing source folder: cadreo
# Found 354 CSV files in source folder: leboncoin
# Processing 50 files from source folder: leboncoin
# Finished processing source folder: leboncoin
# Found 170 CSV files in source folder: cadremploi
# Processing 50 files from source folder: cadremploi
# Finished processing source folder: cadremploi
# Found 361 CSV files in source folder: regionsjob_est
# Processing 50 files from source folder: regionsjob_est
# Finished processing source folder: regionsjob_est
# Found 14 CSV files in source folder: meteojob
# Processing 14 files from source folder: meteojob
# Finished processing source folder: meteojob
# Found 348 CSV files in source folder: bdm
# Processing 50 files from source folder: bdm
# Finished processing source folder: bdm
# Found 363 CSV files in source folder: api_poleemploi
# Processing 50 files from source folder: api_poleemploi
# Finished processing source folder: api_poleemploi
# /var/folders/5z/n4wfh12s55d5j381j6gl47c40000gn/T/ipykernel_43950/1760359826.py:91: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_job = pd.concat(jocas_list, ignore_index=True)
# Total job ads: 1824535

# %%
# ----------------------------------------
# 5. — Gather & (optionally) sample descriptions
# ----------------------------------------
if "description_full" not in df_job.columns:
    raise KeyError("Missing 'description_full' in JOCAS data")

texts = df_job["description_full"].dropna().astype(str)
if isinstance(sample_size, int):
    texts = texts.sample(n=sample_size, random_state=random_seed).tolist()
else:
    texts = texts.tolist()

print(f"Using {len(texts)} job-ad descriptions")

# ----------------------------------------
# 6. — Preprocess & tokenize for phrase detection
# ----------------------------------------
# Each sentence = list of lemmas
sentences = [preprocess_text(doc).split() for doc in texts]

# ----------------------------------------
# 7. — Phrase detection (bigrams & trigrams)
# ----------------------------------------
phrases = Phrases(
    sentences,
    min_count=phrase_min_count,
    threshold=phrase_threshold
)
phraser = Phraser(phrases)
sent_phrased = [phraser[s] for s in sentences]

# ----------------------------------------
# 8. — Inject lemmatized seed expressions
# ----------------------------------------
for expr in attribute_df["expression"].astype(str):
    toks = preprocess_text(expr).split()
    if len(toks) > 1:
        sent_phrased.append(toks)

# ----------------------------------------
# 9. — Train FastText model
# ----------------------------------------
model = FastText(
    sentences=sent_phrased,
    vector_size=vector_size,
    window=window_size,
    min_count=min_count,
    workers=workers,
    seed=random_seed
)

# ----------------------------------------
# 10. — Embedding helper
# ----------------------------------------
def embed(phrase: str) -> np.ndarray | None:
    toks = preprocess_text(phrase).split()
    vecs = [model.wv[t] for t in toks if t in model.wv]
    return np.mean(vecs, axis=0) if vecs else None

# ----------------------------------------
# 11. — Compute category centroids
# ----------------------------------------
cat_centroids = {}
for cat, grp in attribute_df.groupby("attribute_category_fr"):
    vecs = [embed(expr) for expr in grp["expression"]]
    vecs = [v for v in vecs if v is not None]
    if vecs:
        cat_centroids[cat] = np.mean(vecs, axis=0)

# ----------------------------------------
# 12. — Retrieve & filter suggestions
# ----------------------------------------
results = []
for cat, cent in cat_centroids.items():
    raw = model.wv.similar_by_vector(cent, topn=200)
    seeds = cat_to_lemmas[cat]
    kept = []
    for term, sim in raw:
        parts = term.split("_")
        # only keep expressions ≥4 lemmas that share ≥1 seed lemma
        if len(parts) >= 4 and any(p in seeds for p in parts):
            kept.append((term, sim))
        if len(kept) >= 10:
            break
    for term, sim in kept:
        results.append({
            "attribute_category_fr": cat,
            "suggested_expression": term.replace("_", " "),
            "similarity": sim
        })

# ----------------------------------------
# 13. — Preview top-5 per category
# ----------------------------------------
results_df = pd.DataFrame(results)
preview = results_df.groupby("attribute_category_fr").head(5).reset_index(drop=True)
print(preview.to_string(index=False))
# Out:
# Using 50 job-ad descriptions
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 19
#      13 print(f"Using {len(texts)} job-ad descriptions")
#      15 # ----------------------------------------
#      16 # 6. — Preprocess & tokenize for phrase detection
#      17 # ----------------------------------------
#      18 # Each sentence = list of lemmas
# ---> 19 sentences = [preprocess_text(doc).split() for doc in texts]
#      21 # ----------------------------------------
#      22 # 7. — Phrase detection (bigrams & trigrams)
#      23 # ----------------------------------------
#      24 phrases = Phrases(
#      25     sentences,
#      26     min_count=phrase_min_count,
#      27     threshold=phrase_threshold
#      28 )
#
# Cell In[62], line 19, in <listcomp>(.0)
#      13 print(f"Using {len(texts)} job-ad descriptions")
#      15 # ----------------------------------------
#      16 # 6. — Preprocess & tokenize for phrase detection
#      17 # ----------------------------------------
#      18 # Each sentence = list of lemmas
# ---> 19 sentences = [preprocess_text(doc).split() for doc in texts]
#      21 # ----------------------------------------
#      22 # 7. — Phrase detection (bigrams & trigrams)
#      23 # ----------------------------------------
#      24 phrases = Phrases(
#      25     sentences,
#      26     min_count=phrase_min_count,
#      27     threshold=phrase_threshold
#      28 )
#
# Cell In[60], line 56, in preprocess_text(text)
#      54 txt = unidecode(text).lower()
#      55 # Lemmatize & filter
# ---> 56 doc = nlp_stop(txt)
#      57 lemmas = [
#      58     tok.lemma_.lower()
#      59     for tok in doc
#    (...)
#      62        and len(tok.lemma_) > 1
#      63 ]
#      64 return " ".join(lemmas)
#
# NameError: name 'nlp_stop' is not defined

# %%
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
